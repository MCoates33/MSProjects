# %% [markdown]
# ###General Instructions
# In this assignment, you will need to complete the code samples where indicated to accomplish the given objectives. **Be sure to run all cells** and export this notebook as an HTML with results included.  Upload the exported HTML file to Canvas by the assignment deadline.

# %% [markdown]
# ####Assignment
# Unlike previous exercises, you will not be provided any sample code from which to work.  You are given a starting point and an expected outcome.  Use what you have learned in class and in labs to complete the exercise as outlined below. Break your logic up into cells that tackle webpage retrieval, HTML parsing, and DataFrame assembly and persistence.

# %% [markdown]
# Board Game Geek is an online site that provides rankings for various boardgames.  A complete listing of ranked games is provided here: https://boardgamegeek.com/browse/boardgame
#
# The data on this page is organized in a simple table format. The Title field is divided into the game's title and the year it was published. The title itself provides a link to more information on the game.
#
# Write a routine to scrape this data from the page and persist it as a partitioned Parquet table named games.board_games.  Use the current date as the partitioning field.
#
# The fields required in the final table are:
#
# * Rank - the integer value from the Board Game Rank column
# * ImageURL - the URL (as provided) of the image presented in the second column
# * Title - the title of the game
# * YearPublished - the year the game was published
# * GeekRating - the float value presented in the Geek Rating field
# * AvgRating - the float value presented in the Avg Rating field
# * NumVoters - the integer value presented in the NumVoters field
#
# (You can ignore the Shop field)
#
# While the Board Game Geek site has multiple pages of rankings, limit your scraping to the games presented on the page referenced above.  (In other words, don't hit the other 1000+ pages of rankings.)
#
# Once you've populated your table, run the two SQL statements presented at the bottom of this notebook.  Save your notebook (with the results) as an HTML file and load it to Canvas.

# %%
# run this code to make sure beautiful soup is installed
dbutils.library.installPyPI('beautifulsoup4')
dbutils.library.restartPython()
# Out:
# dbutils.library APIs are deprecated and will be removed in a future DBR release. You can use %pip commands to install notebook scoped python libraries.
# PyPI package beautifulsoup4 has been installed already. The previously installed package is `beautifulsoup4`. To resolve this issue, detach and re-attach the notebook to create a new environment or rename the package.

# %%
# %sql -- create games database
create database if not exists games;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
from urllib import request as url

# retrieve the web page
request = url.Request('https://boardgamegeek.com/browse/boardgame')

# submit this request and retrieve a result
response = url.urlopen(request)

html = response.read()

print(html)
# Out:
# b'<!DOCTYPE html>\n<html ng-app="GeekApp" lang="en-US" ng-cloak>\n<head>\n\t<meta charset=\'utf-8\'>\n\t<meta id="vp" name="viewport" content="width=device-width, initial-scale=1.0">\n\t\t\t<script>\n\t\t\twindow.addEventListener( \'DOMContentLoaded\',  function() {\n\t\t\t\tvar width = document.documentElement.clientWidth || window.innerWidth;\n\t\t\t\tif (width < 960) {\n\t\t\t\t\tvar mvp = document.getElementById(\'vp\');\n\t\t\t\t\t// android debugging\n\t\t\t\t\tmvp.setAttribute(\'content\',\'width=960\');\n\t\t\t\t}\n\t\t\t});\n\t\t</script>\n\t\t<meta content=\'yes\' name=\'apple-mobile-web-app-capable\'>\n\t<meta content=\'IE=edge,chrome=1\' http-equiv=\'X-UA-Compatible\'>\n\n\t\t\t<title>Browse Board Games | BoardGameGeek</title>\n\t\n\t\n<link rel="apple-touch-icon" \thref="https://cf.geekdo-static.com/icons/touch-icon180.png" />\n<link rel="shortcut icon" \t\thref="https://cf.geekdo-static.com/icons/favicon2.ico" type="image/ico" />\n<link rel="icon" \t\t\t\t\thref="https://cf.geekdo-static.com/icons/favicon2.ico" type="image/ico" />\n<link rel="search" \t\t\t\thref="/game-opensearch.xml" type="application/opensearchdescription+xml" title="BGG Game Search" />\n<meta name="apple-mobile-web-app-title" content="BGG">\n\n<meta name="theme-color" content="#2e2b47">\n<link rel="preconnect" href="https://api.geekdo.com" />\n\n\n\n\n\t<meta property="og:image" content="https://cf.geekdo-static.com/images/opengraph/bgg_opengraph.png" />\n\n\n\n\t<meta name="keywords" content="board game, boardgames, boardgame, board, games, game, hobby, boardgamegeek, geek, geekdo">\n\n<script>window.AdSlots = window.AdSlots || {\n\tcmd: [],\n\tdisableScripts: [\'gpt\'],\n\trenderOnFirstLoad: false,\n\tdivCheck: false\n};</script>\n\n\n\t\t\t\t\t\t<link rel=\'stylesheet\' type=\'text/css\' href=\'https://cf.geekdo-static.com/static/geekui_master2_623b508612842.css\'>\n\t\t\t\t\t<link rel=\'stylesheet\' type=\'text/css\' href=\'https://cf.geekdo-static.com/static/css_master2_623b507a9b8b9.css\'>\n\t\t\t\n\t<base href="/">\n\n\t<script src="https://kit.fontawesome.com/42d3f5a072.js" crossorigin="anonymous"></script>\n\n<script>\n\tvar GEEK = GEEK || {};\n\tGEEK.adBlock = [];\n\tGEEK.adConfig = {"blockleaderboard":null,"blockskyscraper":null,"noadsense":true,"blocksupportdrive":null};\n\tGEEK.adSlots = {"dfp-leaderboard":{"name":"boardgame_leaderboard_728x90"},"dfp-skyscraper":{"name":"boardgame_skyscraper_160x600"},"dfp-medrect":{"name":"boardgame_rectangle_300x250"},"dfp-repeater":{"name":"boardgame_home_repeater"},"dfp-medrect-reserved-home":{"name":"boardgame_reserved_home_300x250"},"dfp-leaderboard-lg":{"name":"boardgame_home_hero"},"dfp-home-sidekick":{"name":"boardgame_home_sidekick"}};\n\tGEEK.googleTargets = null;\n\tGEEK.userid = 0;\n\tGEEK.domainname = \'boardgamegeek.com\';\n\tGEEK.domain = \'boardgame\';\n\tGEEK.geekitemPreload = {};\n\tGEEK.geekitemSettings = null;\n\tGEEK.geekitemModules = null;\n\tGEEK.geekGlobalSettings = {"shutdown_file_ops":"1","shutdown_storeimage_ops":"0","shutdown_edit_avatar":"0","shutdown_file_upload":"0","shutdown_file_download":"0","shutdown_image_upload":"0"};\n\tGEEK.geekimageSettings = null;\n\tGEEK.legacy = 1;\n\tGEEK.apiurlsPrefix = \'https://api.geekdo.com\';\n\n\t\n\t\t\n\t\tGEEK.apiurls = {\n\t\t\'amazon\': \'/api/amazon\',\n\t\t\'files\': \'/api/files\',\n\t\t\'geekitems\': \'/api/geekitems\',\n\t\t\'images\': \'/api/images\',\n\t\t\'threads\': \'/api/forums/threads\',\n\t \t\'forums\': \'/api/forums\',\n\t\t\'videos\': \'/api/videos\',\n\t\t\'hotness\': \'/api/hotness\',\n\t\t\'dynamicinfo\': \'/api/dynamicinfo\',\n\t\t\'subtypeinfo\': \'/api/subtypeinfo\',\n\t\t\'geekbay\': \'/api/geekbay\',\n\t\t\'geekmarket\': \'/geekmarket/api/v1\',\n\t    \'geekmarketapi\': \'/api/geekmarket\',\n\t\t\'geeklists\': \'/api/geeklists\',\n\t\t\'reviews\': \'/api/forumreviews\',\n\t\t\'collections\': \'/api/collections\',\n\t\t\'linkeditems\': \'/api/geekitem/linkeditems\',\n\t\t\'subscriptions\': \'/api/subs ...

# %%
from bs4 import BeautifulSoup

# load raw html into beautiful soup
soup = BeautifulSoup(html)

# print beautiful soup html
print( soup )
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" ng-app="GeekApp" ng-cloak="">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" id="vp" name="viewport"/>
# <script>
# 			window.addEventListener( 'DOMContentLoaded',  function() {
# 				var width = document.documentElement.clientWidth || window.innerWidth;
# 				if (width < 960) {
# 					var mvp = document.getElementById('vp');
# 					// android debugging
# 					mvp.setAttribute('content','width=960');
# 				}
# 			});
# 		</script>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Browse Board Games | BoardGameGeek</title>
# <link href="https://cf.geekdo-static.com/icons/touch-icon180.png" rel="apple-touch-icon"/>
# <link href="https://cf.geekdo-static.com/icons/favicon2.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://cf.geekdo-static.com/icons/favicon2.ico" rel="icon" type="image/ico"/>
# <link href="/game-opensearch.xml" rel="search" title="BGG Game Search" type="application/opensearchdescription+xml"/>
# <meta content="BGG" name="apple-mobile-web-app-title"/>
# <meta content="#2e2b47" name="theme-color"/>
# <link href="https://api.geekdo.com" rel="preconnect"/>
# <meta content="https://cf.geekdo-static.com/images/opengraph/bgg_opengraph.png" property="og:image">
# <meta content="board game, boardgames, boardgame, board, games, game, hobby, boardgamegeek, geek, geekdo" name="keywords"/>
# <script>window.AdSlots = window.AdSlots || {
# 	cmd: [],
# 	disableScripts: ['gpt'],
# 	renderOnFirstLoad: false,
# 	divCheck: false
# };</script>
# <link href="https://cf.geekdo-static.com/static/geekui_master2_623b508612842.css" rel="stylesheet" type="text/css"/>
# <link href="https://cf.geekdo-static.com/static/css_master2_623b507a9b8b9.css" rel="stylesheet" type="text/css"/>
# <base href="/"/>
# <script crossorigin="anonymous" src="https://kit.fontawesome.com/42d3f5a072.js"></script>
# <script>
# 	var GEEK = GEEK || {};
# 	GEEK.adBlock = [];
# 	GEEK.adConfig = {"blockleaderboard":null,"blockskyscraper":null,"noadsense":true,"blocksupportdrive":null};
# 	GEEK.adSlots = {"dfp-leaderboard":{"name":"boardgame_leaderboard_728x90"},"dfp-skyscraper":{"name":"boardgame_skyscraper_160x600"},"dfp-medrect":{"name":"boardgame_rectangle_300x250"},"dfp-repeater":{"name":"boardgame_home_repeater"},"dfp-medrect-reserved-home":{"name":"boardgame_reserved_home_300x250"},"dfp-leaderboard-lg":{"name":"boardgame_home_hero"},"dfp-home-sidekick":{"name":"boardgame_home_sidekick"}};
# 	GEEK.googleTargets = null;
# 	GEEK.userid = 0;
# 	GEEK.domainname = 'boardgamegeek.com';
# 	GEEK.domain = 'boardgame';
# 	GEEK.geekitemPreload = {};
# 	GEEK.geekitemSettings = null;
# 	GEEK.geekitemModules = null;
# 	GEEK.geekGlobalSettings = {"shutdown_file_ops":"1","shutdown_storeimage_ops":"0","shutdown_edit_avatar":"0","shutdown_file_upload":"0","shutdown_file_download":"0","shutdown_image_upload":"0"};
# 	GEEK.geekimageSettings = null;
# 	GEEK.legacy = 1;
# 	GEEK.apiurlsPrefix = 'https://api.geekdo.com';
#
#
#
# 		GEEK.apiurls = {
# 		'amazon': '/api/amazon',
# 		'files': '/api/files',
# 		'geekitems': '/api/geekitems',
# 		'images': '/api/images',
# 		'threads': '/api/forums/threads',
# 	 	'forums': '/api/forums',
# 		'videos': '/api/videos',
# 		'hotness': '/api/hotness',
# 		'dynamicinfo': '/api/dynamicinfo',
# 		'subtypeinfo': '/api/subtypeinfo',
# 		'geekbay': '/api/geekbay',
# 		'geekmarket': '/geekmarket/api/v1',
# 	    'geekmarketapi': '/api/geekmarket',
# 		'geeklists': '/api/geeklists',
# 		'reviews': '/api/forumreviews',
# 		'collections': '/api/collections',
# 		'linkeditems': '/api/geekitem/linkeditems',
# 		'subscriptions': '/api/subscriptions',
# 	    'fans': '/api/fans',
# 	    'geekpreviews': '/api/geekpreviews',
# 	    'geekpreviewitems': '/api/geekpreviewitems',
# 	   	'geekpreviewparentitems': '/api/geekpreviewparentitems',
# 		'recs': '/api/geekitem/recs',
# 	    'awards': '/api/geekawards',
# 		'historicalrankgraph':  '/api/historicalrankgraph',
# 		'blueprint_recipes': '/api/blueprints/recipes'
# 	};
# </script>
# <script src="https://cf.geekdo-static.com/static/geekangular17_master2_623b509276f17.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/geekui_master2_623b508612842.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/js_master2_623b507a3a225.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/geekoutputtemplates_master2_623b509329379.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/geekuicommontemplates_master2_623b509330690.js" type="text/javascript"></script>
# <!-- why this? -->
# <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <!-- Add to main?
# <link rel="apple-touch-icon" 	href="https://cf.geekdo-static.com/icons/appleicon.png" />
# <link rel="shortcut icon" 		href="https://cf.geekdo-static.com/icons/favicon.ico" type="image/ico" />
# <link rel="icon" 					href="https://cf.geekdo-static.com/icons/favicon.ico" type="image/ico" />
# <link rel="search" 				href="/game-opensearch.xml" type="application/opensearchdescription+xml" title="BGG Game Search" />
# -->
# <!--this is used only for GeekMap -->
# <!-- deal with adsense
# 	<script type="text/javascript">
# 		window.google_analytics_uacct = "UA-104725-1";
# 		var googletag = googletag || { };
# 		googletag.cmd = googletag.cmd || [];
# 		( function() {
# 			var gads = document.createElement('script');
# 			gads.async = true;
# 			gads.type  = 'text/javascript';
# 			gads.src   = "//www.googletagservices.com/tag/js/gpt.js";
# 			var node = document.getElementsByTagName('script')[0];
# 			node.parentNode.insertBefore(gads, node);
# 		} )();
#
# 		adunits = [
# 			{
# 				name:    'boardgame_button_120x45',
# 				size:    [ 120, 45 ],
# 				target:  'dfp-button'
# 			},
# 			{
# 				name:    'boardgame_leaderboard_728x90',
# 				size:    [ 728, 90 ],
# 				target:  'dfp-leaderboard'
# 			},
# 			{
# 				name:    'boardgame_skyscraper_160x600',
# 				size:    [ 160, 600 ],
# 				target:  'dfp-skyscraper'
# 			},
# 			{
# 				name:    'boardgame_rectangle_300x250',
# 				size:    [ 300, 250 ],
# 				target:  'dfp-medrect'
# 			},
# 			{
# 				name:    'boardgame_rectangle_300x250',
# 				size:    [ 300, 250 ],
# 				target:  'dfp-medrect-reserved-home'
# 			},
# 			{
# 				name:    'boardgame_button_120x90',
# 				size:    [ 120, 90 ],
# 				target:  'dfp-giftguide'
# 			}
# 		];
#
# 		googletag.cmd.push(function() {
# 			for( var i=0; i< adunits.length; i++ )
# 			{
# 				unit = adunits[i];
# 				googletag.defineUnit('/1005854/ca-pub-7206761047394129/'+unit.name, unit.size, unit.target).
# 				addService(googletag.pubads());
# 			}
#
#
# 			googletag.pubads().setTargeting( "subdomain", "all" );
# 			googletag.enableServices();
# 		} );
#
# 	</script>
# -->
# <script>
# 	function start() {
#
# 	}
#
# 	function ondomready() {
# 				Amazon_LoadAds();
#
# 		GEEK.addHandlers();
# 		GEEK.recaptchaKey = '6Ldyr6EaAAAAAE0F2hYgtHHqbF6nKPTENAwo6SyU';
# 	}
#
# 	if( typeof window.addEvent === "function" ) {
# 		window.addEvent('domready', function() {
# 			ondomready();
# 		} );
# 	} else {
# 		window.addEventListener( "DOMContentLoaded", function() {
# 			ondomready();
# 	} );
# 	}
# 	window.onload = start;
# </script>
# </meta></head>
# <body class="domain-boardgame" ng-class="{ 'has-no-max-width' : layoutctrl.geekitemSettings.fluidlayout }" ng-controller="GeekOutput_LayoutCtrl as layoutctrl">
# <div class="d-flex flex-column min-vh-100">
# <div hide-ad-block="blockleaderboard">
# <div class="advertisement advertisement-leaderboard">
# <div class="center-block" ng-dfp-ad="dfp-leaderboard"></div>
# </div>
# </div>
# <div class="global-header-outer" click-out="navctrl.closeMobileMenu()" id="global-header-outer" ng-controller="NavCtrl as navctrl">
# <geeknav-menu></geeknav-menu>
# </div>
# <main class="global-body flex-grow-1" id="mainbody" ng-class="{ 'has-overlay-sidebar': layoutctrl.showOverlaySidebar, 'has-hidden-fixed-sidebar': layoutctrl.localStorage.hideFixedSidebar }">
# <a id="mainbodytarget" tabindex="-1"></a>
# <!-- Home King Ad -->
# <div class="global-body-content-container container-fluid">
# <geekoutput-sidebar deactivate-overlay-sidebar="layoutctrl.deactivateOverlaySidebar" show-overlay-sidebar="layoutctrl.showOverlaySidebar"></geekoutput-sidebar>
# <div class="global-body-content pending" ng-class="{'ready': layoutctrl.ready}">
# <a id="maincontenttarget" tabindex="-1"></a>
# <div class="legacy">
# <div class="yui-skin-sam" id="container">
# <div id="maincontent" ng-non-bindable="">
# <form action="" method="GET">
# <div class="infobox">
# <div class="fr"><b>1</b> , <a href="/browse/boardgame/page/2" target="_self" title="page 2">2</a> , <a href="/browse/boardgame/page/3" target="_self" title="page 3">3</a> , <a href="/browse/boardgame/page/4" target="_self" title="page 4">4</a> , <a href="/browse/boardgame/page/5" target="_self" title="page 5">5</a>  <a href="/browse/boardgame/page/2" target="_self" title="next page"><b>Next »</b></a>  <a href="/browse/boardgame/page/1353" target="_self" title="last page">[1353]</a></div>
# <div class="clear"></div>
# </div>
# </form>
# <div id="collection_status" style="position:absolute; background:red; color:white;"></div>
# <div id="collection"><div class="fl sf"><span id="collection_viewlabel" style="display:none;"> | View: <span id="collection_viewname"></span></span></div>
# <div class="sf" style="text-align:right; margin-bottom:5px;">
# </div>
# <div class="table-responsive">
# <table cellpadding="0" cellspacing="1" class="collection_table" id="collectionitems" width="100%">
# <tr>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=rank&amp;sortdir=desc">Board Game Rank<img alt="ascending sort" border="0" hspace="5" src="https://cf.geekdo-static.com/images/collection/arrow_up.gif"/></a>
# </th>
# <th class="collection_thumbnail">
# <span class="sr-only">Thumbnail image</span>
# </th>
# <th class="collection_title">
# <a href="/browse/boardgame?sort=title">Title</a>
# </th>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=bggrating">Geek Rating</a>
# </th>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=avgrating">Avg Rating</a>
# </th>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=numvoters">Num Voters</a>
# </th>
# <th class="collection_shop">
# 			Shop
# 		</th>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="1"></a>			1
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/174430/gloomhaven"><img alt="Board Game: Gloomhaven" src="https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__micro/img/sQyh47ClBO3d5sxPm73hMvM-JV4=/fit-in/64x64/filters:strip_icc()/pic2437871.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname1">
# <div id="status_objectname1"></div>
# <div id="results_objectname1" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/174430/gloomhaven">Gloomhaven</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Vanquish monsters with strategic cardplay. Fulfill your quest to leave your legacy!
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.499		</td>
# <td align="center" class="collection_bggrating">
# 			8.73		</td>
# <td align="center" class="collection_bggrating">
# 			49467		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_174430_textwithprices__"></div>
# 																	[<a href="/boardgame/174430/gloomhaven/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="2"></a>			2
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/161936/pandemic-legacy-season-1"><img alt="Board Game: Pandemic Legacy: Season 1" src="https://cf.geekdo-images.com/-Qer2BBPG7qGGDu6KcVDIw__micro/img/n6-sXYD6XXZoqIxq4P6AG7VPCuA=/fit-in/64x64/filters:strip_icc()/pic2452831.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname2">
# <div id="status_objectname2"></div>
# <div id="results_objectname2" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/161936/pandemic-legacy-season-1">Pandemic Legacy: Season 1</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Mutating diseases are spreading around the world - can your team save humanity?
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.437		</td>
# <td align="center" class="collection_bggrating">
# 			8.59		</td>
# <td align="center" class="collection_bggrating">
# 			46063		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_161936_textwithprices__"></div>
# 																	[<a href="/boardgame/161936/pandemic-legacy-season-1/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="3"></a>			3
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/224517/brass-birmingham"><img alt="Board Game: Brass: Birmingham" src="https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__micro/img/4Od3GYCiqptga0VbmyumPbJlBsU=/fit-in/64x64/filters:strip_icc()/pic3490053.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname3">
# <div id="status_objectname3"></div>
# <div id="results_objectname3" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/224517/brass-birmingham">Brass: Birmingham</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build networks, grow industries, and navigate the world of the Industrial Revolution.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.422		</td>
# <td align="center" class="collection_bggrating">
# 			8.66		</td>
# <td align="center" class="collection_bggrating">
# 			27313		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_224517_textwithprices__"></div>
# 																	[<a href="/boardgame/224517/brass-birmingham/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="4"></a>			4
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/167791/terraforming-mars"><img alt="Board Game: Terraforming Mars" src="https://cf.geekdo-images.com/wg9oOLcsKvDesSUdZQ4rxw__micro/img/LUkXZhd1TO80eCiXMD3-KfnzA6k=/fit-in/64x64/filters:strip_icc()/pic3536616.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname4">
# <div id="status_objectname4"></div>
# <div id="results_objectname4" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/167791/terraforming-mars">Terraforming Mars</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Compete with rival CEOs to make Mars habitable and build your corporate empire.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.269		</td>
# <td align="center" class="collection_bggrating">
# 			8.41		</td>
# <td align="center" class="collection_bggrating">
# 			77092		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_167791_textwithprices__"></div>
# 																	[<a href="/boardgame/167791/terraforming-mars/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="5"></a>			5
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/291457/gloomhaven-jaws-lion"><img alt="Board Game: Gloomhaven: Jaws of the Lion" src="https://cf.geekdo-images.com/_HhIdavYW-hid20Iq3hhmg__micro/img/OdKjWiFsNvQAfJfXXSITttiozWE=/fit-in/64x64/filters:strip_icc()/pic5055631.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname5">
# <div id="status_objectname5"></div>
# <div id="results_objectname5" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/291457/gloomhaven-jaws-lion">Gloomhaven: Jaws of the Lion</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Vanquish monsters with strategic cardplay in a 25-scenario Gloomhaven campaign.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.267		</td>
# <td align="center" class="collection_bggrating">
# 			8.65		</td>
# <td align="center" class="collection_bggrating">
# 			18306		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_291457_textwithprices__"></div>
# 																	[<a href="/boardgame/291457/gloomhaven-jaws-lion/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="6"></a>			6
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/233078/twilight-imperium-fourth-edition"><img alt="Board Game: Twilight Imperium: Fourth Edition" src="https://cf.geekdo-images.com/_Ppn5lssO5OaildSE-FgFA__micro/img/2gymaKs35_2yj7eyyA6cYyVmd9c=/fit-in/64x64/filters:strip_icc()/pic3727516.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname6">
# <div id="status_objectname6"></div>
# <div id="results_objectname6" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/233078/twilight-imperium-fourth-edition">Twilight Imperium: Fourth Edition</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build an intergalactic empire through trade, research, conquest and grand politics.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.256		</td>
# <td align="center" class="collection_bggrating">
# 			8.66		</td>
# <td align="center" class="collection_bggrating">
# 			16792		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_233078_textwithprices__"></div>
# 																	[<a href="/boardgame/233078/twilight-imperium-fourth-edition/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="7"></a>			7
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/220308/gaia-project"><img alt="Board Game: Gaia Project" src="https://cf.geekdo-images.com/hGWFm3hbMlCDsfCsauOQ4g__micro/img/odWj2bEnZi9dEcQQrOtYj1e0QLE=/fit-in/64x64/filters:strip_icc()/pic5375625.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname7">
# <div id="status_objectname7"></div>
# <div id="results_objectname7" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/220308/gaia-project">Gaia Project</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Expand, research, upgrade, and settle the galaxy with one of 14 alien species.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.173		</td>
# <td align="center" class="collection_bggrating">
# 			8.47		</td>
# <td align="center" class="collection_bggrating">
# 			20213		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_220308_textwithprices__"></div>
# 																	[<a href="/boardgame/220308/gaia-project/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="8"></a>			8
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/187645/star-wars-rebellion"><img alt="Board Game: Star Wars: Rebellion" src="https://cf.geekdo-images.com/7SrPNGBKg9IIsP4UQpOi8g__micro/img/nEvTiCkWpT-ymH4bstc9c335TtQ=/fit-in/64x64/filters:strip_icc()/pic4325841.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname8">
# <div id="status_objectname8"></div>
# <div id="results_objectname8" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/187645/star-wars-rebellion">Star Wars: Rebellion</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Strike from your hidden base as the Rebels—or find and destroy it as the Empire.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.169		</td>
# <td align="center" class="collection_bggrating">
# 			8.42		</td>
# <td align="center" class="collection_bggrating">
# 			26313		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_187645_textwithprices__"></div>
# 																	[<a href="/boardgame/187645/star-wars-rebellion/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="9"></a>			9
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/162886/spirit-island"><img alt="Board Game: Spirit Island" src="https://cf.geekdo-images.com/a13ieMPP2s0KEaKNYmtH5w__micro/img/HQaHfx5cy6wJtZBMZCbVeNbfdy8=/fit-in/64x64/filters:strip_icc()/pic3615739.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname9">
# <div id="status_objectname9"></div>
# <div id="results_objectname9" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/162886/spirit-island">Spirit Island</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Island Spirits join forces using elemental powers to defend their home from invaders.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.142		</td>
# <td align="center" class="collection_bggrating">
# 			8.36		</td>
# <td align="center" class="collection_bggrating">
# 			34294		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_162886_textwithprices__"></div>
# 																	[<a href="/boardgame/162886/spirit-island/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="10"></a>			10
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/115746/war-ring-second-edition"><img alt="Board Game: War of the Ring: Second Edition" src="https://cf.geekdo-images.com/ImPgGag98W6gpV1KV812aA__micro/img/NT-Av_3kdYUcwuti5ocmIQXow3g=/fit-in/64x64/filters:strip_icc()/pic1215633.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname10">
# <div id="status_objectname10"></div>
# <div id="results_objectname10" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/115746/war-ring-second-edition">War of the Ring: Second Edition</a>
# <span class="smallerfont dull">(2011)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			The Fellowship and the Free Peoples clash with Sauron over the fate of Middle-Earth.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.141		</td>
# <td align="center" class="collection_bggrating">
# 			8.52		</td>
# <td align="center" class="collection_bggrating">
# 			16056		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_115746_textwithprices__"></div>
# 																	[<a href="/boardgame/115746/war-ring-second-edition/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="11"></a>			11
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/182028/through-ages-new-story-civilization"><img alt="Board Game: Through the Ages: A New Story of Civilization" src="https://cf.geekdo-images.com/fVwPntkJKgaEo0rIC0RwpA__micro/img/77dZJpqtydc8TTecl0ReGF7iAVw=/fit-in/64x64/filters:strip_icc()/pic2663291.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname11">
# <div id="status_objectname11"></div>
# <div id="results_objectname11" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/182028/through-ages-new-story-civilization">Through the Ages: A New Story of Civilization</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Rewrite history as you build up your civilization in this epic card drafting game!
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.141		</td>
# <td align="center" class="collection_bggrating">
# 			8.37		</td>
# <td align="center" class="collection_bggrating">
# 			26312		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_182028_textwithprices__"></div>
# 																	[<a href="/boardgame/182028/through-ages-new-story-civilization/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="12"></a>			12
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/193738/great-western-trail"><img alt="Board Game: Great Western Trail" src="https://cf.geekdo-images.com/u1l0gH7sb_vnvDvoO_QHqA__micro/img/xeShpQfbj4L1id-ItJbfIYVzgyA=/fit-in/64x64/filters:strip_icc()/pic4887376.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname12">
# <div id="status_objectname12"></div>
# <div id="results_objectname12" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/193738/great-western-trail">Great Western Trail</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Use strategic outposts and navigate danger as you herd your cattle to Kansas City.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.120		</td>
# <td align="center" class="collection_bggrating">
# 			8.29		</td>
# <td align="center" class="collection_bggrating">
# 			33958		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_193738_textwithprices__"></div>
# 																	[<a href="/boardgame/193738/great-western-trail/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="13"></a>			13
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/12333/twilight-struggle"><img alt="Board Game: Twilight Struggle" src="https://cf.geekdo-images.com/pNCiUUphnoeWOYfsWq0kng__micro/img/ZlfJiIATIt5MY7xWSMzFmdygaa0=/fit-in/64x64/filters:strip_icc()/pic3530661.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname13">
# <div id="status_objectname13"></div>
# <div id="results_objectname13" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/12333/twilight-struggle">Twilight Struggle</a>
# <span class="smallerfont dull">(2005)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Relive the Cold War and rewrite history in an epic clash between the USA and USSR.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.110		</td>
# <td align="center" class="collection_bggrating">
# 			8.28		</td>
# <td align="center" class="collection_bggrating">
# 			43671		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_12333_textwithprices__"></div>
# 																	[<a href="/boardgame/12333/twilight-struggle/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="14"></a>			14
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/169786/scythe"><img alt="Board Game: Scythe" src="https://cf.geekdo-images.com/7k_nOxpO9OGIjhLq2BUZdA__micro/img/ETplc22GdhlN5u0mppcDxSP8LVk=/fit-in/64x64/filters:strip_icc()/pic3163924.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname14">
# <div id="status_objectname14"></div>
# <div id="results_objectname14" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/169786/scythe">Scythe</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Five factions vie for dominance in a war-torn, mech-filled, dieselpunk 1920s Europe.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.059		</td>
# <td align="center" class="collection_bggrating">
# 			8.21		</td>
# <td align="center" class="collection_bggrating">
# 			66884		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_169786_textwithprices__"></div>
# 																	[<a href="/boardgame/169786/scythe/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="15"></a>			15
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/316554/dune-imperium"><img alt="Board Game: Dune: Imperium" src="https://cf.geekdo-images.com/PhjygpWSo-0labGrPBMyyg__micro/img/mfU7-dEFnVyXJrF-BWAO0buexao=/fit-in/64x64/filters:strip_icc()/pic5666597.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname15">
# <div id="status_objectname15"></div>
# <div id="results_objectname15" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/316554/dune-imperium">Dune: Imperium</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Influence, intrigue, and combat in the universe of Dune.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.018		</td>
# <td align="center" class="collection_bggrating">
# 			8.33		</td>
# <td align="center" class="collection_bggrating">
# 			18424		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_316554_textwithprices__"></div>
# 																	[<a href="/boardgame/316554/dune-imperium/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="16"></a>			16
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/84876/castles-burgundy"><img alt="Board Game: The Castles of Burgundy" src="https://cf.geekdo-images.com/5CFwjd8zTcGYVUnkXh04hw__micro/img/N1VrEUaW6bmwnqbZfi2nRScwGxM=/fit-in/64x64/filters:strip_icc()/pic1176894.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname16">
# <div id="status_objectname16"></div>
# <div id="results_objectname16" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/84876/castles-burgundy">The Castles of Burgundy</a>
# <span class="smallerfont dull">(2011)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Plan, trade, and build your Burgundian estate to prosperity and prominence.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.006		</td>
# <td align="center" class="collection_bggrating">
# 			8.13		</td>
# <td align="center" class="collection_bggrating">
# 			51864		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_84876_textwithprices__"></div>
# 																	[<a href="/boardgame/84876/castles-burgundy/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="17"></a>			17
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/167355/nemesis"><img alt="Board Game: Nemesis" src="https://cf.geekdo-images.com/tAqLpWxQ0Oo3GaPP3MER1g__micro/img/tivhH093LwCowK-_S7bVF_xha34=/fit-in/64x64/filters:strip_icc()/pic5073276.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname17">
# <div id="status_objectname17"></div>
# <div id="results_objectname17" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/167355/nemesis">Nemesis</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Survive an alien-infested spaceship but beware of other players and their agendas.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.987		</td>
# <td align="center" class="collection_bggrating">
# 			8.38		</td>
# <td align="center" class="collection_bggrating">
# 			19175		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_167355_textwithprices__"></div>
# 																	[<a href="/boardgame/167355/nemesis/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="18"></a>			18
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/173346/7-wonders-duel"><img alt="Board Game: 7 Wonders Duel" src="https://cf.geekdo-images.com/WzNs1mA_o22ZWTR8fkLP2g__micro/img/xh3isprMbt_FCg9vs3w_ifv-JXY=/fit-in/64x64/filters:strip_icc()/pic3376065.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname18">
# <div id="status_objectname18"></div>
# <div id="results_objectname18" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/173346/7-wonders-duel">7 Wonders Duel</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Science? Military? What will you draft to win this head-to-head version of 7 Wonders?
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.983		</td>
# <td align="center" class="collection_bggrating">
# 			8.11		</td>
# <td align="center" class="collection_bggrating">
# 			72475		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_173346_textwithprices__"></div>
# 																	[<a href="/boardgame/173346/7-wonders-duel/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="19"></a>			19
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/124361/concordia"><img alt="Board Game: Concordia" src="https://cf.geekdo-images.com/CzwSm8i7tkLz6cBnrILZBg__micro/img/FQyxREkHBn7yTbGmBg7c44eLgaM=/fit-in/64x64/filters:strip_icc()/pic3453267.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname19">
# <div id="status_objectname19"></div>
# <div id="results_objectname19" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/124361/concordia">Concordia</a>
# <span class="smallerfont dull">(2013)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Lead your Roman dynasty and build the greatest trading empire in the Mediterranean.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.968		</td>
# <td align="center" class="collection_bggrating">
# 			8.12		</td>
# <td align="center" class="collection_bggrating">
# 			32560		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_124361_textwithprices__"></div>
# 																	[<a href="/boardgame/124361/concordia/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="20"></a>			20
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/28720/brass-lancashire"><img alt="Board Game: Brass: Lancashire" src="https://cf.geekdo-images.com/tHVtPzu82mBpeQbbZkV6EA__micro/img/jM8d5Q5btvJmcWQN_px-A-nlueI=/fit-in/64x64/filters:strip_icc()/pic3469216.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname20">
# <div id="status_objectname20"></div>
# <div id="results_objectname20" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/28720/brass-lancashire">Brass: Lancashire</a>
# <span class="smallerfont dull">(2007)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Test your economic mettle as you build and network in the Industrial Revolution.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.966		</td>
# <td align="center" class="collection_bggrating">
# 			8.18		</td>
# <td align="center" class="collection_bggrating">
# 			21314		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_28720_textwithprices__"></div>
# 																	[<a href="/boardgame/28720/brass-lancashire/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="21"></a>			21
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/120677/terra-mystica"><img alt="Board Game: Terra Mystica" src="https://cf.geekdo-images.com/bre12I1YiXkZr7elvriz4A__micro/img/SAwaBrDhHbGuq6dFY-ok95qFMcU=/fit-in/64x64/filters:strip_icc()/pic5375624.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname21">
# <div id="status_objectname21"></div>
# <div id="results_objectname21" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/120677/terra-mystica">Terra Mystica</a>
# <span class="smallerfont dull">(2012)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Play fantastical factions.  Expand your influence by terraforming and joining cults.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.958		</td>
# <td align="center" class="collection_bggrating">
# 			8.12		</td>
# <td align="center" class="collection_bggrating">
# 			42539		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_120677_textwithprices__"></div>
# 																	[<a href="/boardgame/120677/terra-mystica/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="22"></a>			22
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/177736/feast-odin"><img alt="Board Game: A Feast for Odin" src="https://cf.geekdo-images.com/s9oGMCo1fcfV4Dk3EnqLZw__micro/img/JCrcuFDrjVQ64uLbqpH-Pmg6XsU=/fit-in/64x64/filters:strip_icc()/pic3146943.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname22">
# <div id="status_objectname22"></div>
# <div id="results_objectname22" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/177736/feast-odin">A Feast for Odin</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Puzzle together the life of a Viking village as you hunt, farm, craft, and explore.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.953		</td>
# <td align="center" class="collection_bggrating">
# 			8.20		</td>
# <td align="center" class="collection_bggrating">
# 			21370		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_177736_textwithprices__"></div>
# 																	[<a href="/boardgame/177736/feast-odin/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="23"></a>			23
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/266192/wingspan"><img alt="Board Game: Wingspan" src="https://cf.geekdo-images.com/yLZJCVLlIx4c7eJEWUNJ7w__micro/img/5ZaRePVhfelfofF7T_OC1e0gUCw=/fit-in/64x64/filters:strip_icc()/pic4458123.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname23">
# <div id="status_objectname23"></div>
# <div id="results_objectname23" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/266192/wingspan">Wingspan</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Attract a beautiful and diverse collection of birds to your wildlife reserve.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.943		</td>
# <td align="center" class="collection_bggrating">
# 			8.10		</td>
# <td align="center" class="collection_bggrating">
# 			60195		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_266192_textwithprices__"></div>
# 																	[<a href="/boardgame/266192/wingspan/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="24"></a>			24
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/205637/arkham-horror-card-game"><img alt="Board Game: Arkham Horror: The Card Game" src="https://cf.geekdo-images.com/RdCWCXPnBGSxoOhk5Hkq_g__micro/img/TVx3_34ywzwURntW1WMKBx6ZeCg=/fit-in/64x64/filters:strip_icc()/pic6530423.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname24">
# <div id="status_objectname24"></div>
# <div id="results_objectname24" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/205637/arkham-horror-card-game">Arkham Horror: The Card Game</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Investigate the horrors of Arkham while courting cosmic doom.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.926		</td>
# <td align="center" class="collection_bggrating">
# 			8.16		</td>
# <td align="center" class="collection_bggrating">
# 			34490		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_205637_textwithprices__"></div>
# 																	[<a href="/boardgame/205637/arkham-horror-card-game/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="25"></a>			25
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/183394/viticulture-essential-edition"><img alt="Board Game: Viticulture Essential Edition" src="https://cf.geekdo-images.com/l_PRU2lVlX9seScRFcvFlA__micro/img/3EqHlTkNSnZNFHVaAeFSpzfzuIQ=/fit-in/64x64/filters:strip_icc()/pic6500949.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname25">
# <div id="status_objectname25"></div>
# <div id="results_objectname25" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/183394/viticulture-essential-edition">Viticulture Essential Edition</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Create the most prosperous winery in Italy from the Tuscan vineyard you've inherited.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.891		</td>
# <td align="center" class="collection_bggrating">
# 			8.05		</td>
# <td align="center" class="collection_bggrating">
# 			36505		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_183394_textwithprices__"></div>
# 																	[<a href="/boardgame/183394/viticulture-essential-edition/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="26"></a>			26
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/237182/root"><img alt="Board Game: Root" src="https://cf.geekdo-images.com/JUAUWaVUzeBgzirhZNmHHw__micro/img/tdHLiMYfi-KTy89sGBGZVeE9ts0=/fit-in/64x64/filters:strip_icc()/pic4254509.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname26">
# <div id="status_objectname26"></div>
# <div id="results_objectname26" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/237182/root">Root</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Decide the fate of the forest as woodland factions fight for contrasting goals.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.889		</td>
# <td align="center" class="collection_bggrating">
# 			8.10		</td>
# <td align="center" class="collection_bggrating">
# 			33655		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_237182_textwithprices__"></div>
# 																	[<a href="/boardgame/237182/root/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="27"></a>			27
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/164928/orleans"><img alt="Board Game: Orléans" src="https://cf.geekdo-images.com/nagl1li6kYt9elV9jbfVQw__micro/img/hUKCvnqgFvTl0aOMd8FLkgCObT0=/fit-in/64x64/filters:strip_icc()/pic6228507.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname27">
# <div id="status_objectname27"></div>
# <div id="results_objectname27" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/164928/orleans">Orléans</a>
# <span class="smallerfont dull">(2014)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Craftsmen, scholars &amp; monks can help you reign supreme—but who will turn up to help?
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.884		</td>
# <td align="center" class="collection_bggrating">
# 			8.07		</td>
# <td align="center" class="collection_bggrating">
# 			25390		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_164928_textwithprices__"></div>
# 																	[<a href="/boardgame/164928/orleans/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="28"></a>			28
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/199792/everdell"><img alt="Board Game: Everdell" src="https://cf.geekdo-images.com/fjE7V5LNq31yVEW_yuqI-Q__micro/img/TAgkPCJdNAIHZfn1BE1DXadBL9g=/fit-in/64x64/filters:strip_icc()/pic3918905.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname28">
# <div id="status_objectname28"></div>
# <div id="results_objectname28" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/199792/everdell">Everdell</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Use resources to build a village of critters and constructions in this woodland game.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.882		</td>
# <td align="center" class="collection_bggrating">
# 			8.09		</td>
# <td align="center" class="collection_bggrating">
# 			31949		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_199792_textwithprices__"></div>
# 																	[<a href="/boardgame/199792/everdell/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="29"></a>			29
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/266507/clank-legacy-acquisitions-incorporated"><img alt="Board Game: Clank! Legacy: Acquisitions Incorporated" src="https://cf.geekdo-images.com/hc2NDafu5c24iLJh_IZmyg__micro/img/v2WzacDprYF837E6h9O2WuFFmpw=/fit-in/64x64/filters:strip_icc()/pic4885780.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname29">
# <div id="status_objectname29"></div>
# <div id="results_objectname29" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/266507/clank-legacy-acquisitions-incorporated">Clank!: Legacy – Acquisitions Incorporated</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			"Go forth, be bold, and ACQUIRE!" in this campaign version of "Clank!"
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.876		</td>
# <td align="center" class="collection_bggrating">
# 			8.67		</td>
# <td align="center" class="collection_bggrating">
# 			5536		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_266507_textwithprices__"></div>
# 																	[<a href="/boardgame/266507/clank-legacy-acquisitions-incorporated/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="30"></a>			30
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/96848/mage-knight-board-game"><img alt="Board Game: Mage Knight Board Game" src="https://cf.geekdo-images.com/DUO2hz9AlLOH8p9ED-lCWg__micro/img/eXzdbUmCbIdMIVgiQ_QwS3YNOS4=/fit-in/64x64/filters:strip_icc()/pic1083380.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname30">
# <div id="status_objectname30"></div>
# <div id="results_objectname30" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/96848/mage-knight-board-game">Mage Knight Board Game</a>
# <span class="smallerfont dull">(2011)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build your hero’s spells, abilities, and artifacts as you explore &amp; conquer cities.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.875		</td>
# <td align="center" class="collection_bggrating">
# 			8.10		</td>
# <td align="center" class="collection_bggrating">
# 			29861		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_96848_textwithprices__"></div>
# 																	[<a href="/boardgame/96848/mage-knight-board-game/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="31"></a>			31
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/312484/lost-ruins-arnak"><img alt="Board Game: Lost Ruins of Arnak" src="https://cf.geekdo-images.com/6GqH14TJJhza86BX5HCLEQ__micro/img/2FKVaukjh9a-Kg9LWQuMSvLS34s=/fit-in/64x64/filters:strip_icc()/pic5674958.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname31">
# <div id="status_objectname31"></div>
# <div id="results_objectname31" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/312484/lost-ruins-arnak">Lost Ruins of Arnak</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Explore an island to find resources and discover the lost ruins of Arnak.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.862		</td>
# ...
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/73439/troyes"><img alt="Board Game: Troyes" src="https://cf.geekdo-images.com/fBIe-aEPtJKC-ceNlspK6A__micro/img/6ZLZgf_o1omV4ijqi2OLJWK_GM0=/fit-in/64x64/filters:strip_icc()/pic750583.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname89">
# <div id="status_objectname89"></div>
# <div id="results_objectname89" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/73439/troyes">Troyes</a>
# <span class="smallerfont dull">(2010)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Defend the city and rise to power by influencing the merchants, knights and clergy.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.551		</td>
# <td align="center" class="collection_bggrating">
# 			7.75		</td>
# <td align="center" class="collection_bggrating">
# 			20601		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_73439_textwithprices__"></div>
# 																	[<a href="/boardgame/73439/troyes/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="90"></a>			90
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/40834/dominion-intrigue"><img alt="Board Game: Dominion: Intrigue" src="https://cf.geekdo-images.com/OGOmpi0GgwOwH2y28QgkuA__micro/img/VlsgqS2v915vSCwTPVWFVms0-TY=/fit-in/64x64/filters:strip_icc()/pic460011.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname90">
# <div id="status_objectname90"></div>
# <div id="results_objectname90" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/40834/dominion-intrigue">Dominion: Intrigue</a>
# <span class="smallerfont dull">(2009)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Enlist torturers, swindlers, and saboteurs to gain wealth and dominate the kingdom.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.549		</td>
# <td align="center" class="collection_bggrating">
# 			7.71		</td>
# <td align="center" class="collection_bggrating">
# 			31545		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_40834_textwithprices__"></div>
# 																	[<a href="/boardgame/40834/dominion-intrigue/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="91"></a>			91
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/269385/lord-rings-journeys-middle-earth"><img alt="Board Game: The Lord of the Rings: Journeys in Middle-Earth" src="https://cf.geekdo-images.com/1XA2-niwTBa0HEB7hOz3Dw__micro/img/yhbf5YV6KtavOaIVcFC1ZrDQE_0=/fit-in/64x64/filters:strip_icc()/pic4530974.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname91">
# <div id="status_objectname91"></div>
# <div id="results_objectname91" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/269385/lord-rings-journeys-middle-earth">The Lord of the Rings: Journeys in Middle-Earth</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Heroes explore Middle-earth, working together to combat evil in an epic campaign.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.548		</td>
# <td align="center" class="collection_bggrating">
# 			8.00		</td>
# <td align="center" class="collection_bggrating">
# 			11918		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_269385_textwithprices__"></div>
# 																	[<a href="/boardgame/269385/lord-rings-journeys-middle-earth/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="92"></a>			92
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/170042/raiders-north-sea"><img alt="Board Game: Raiders of the North Sea" src="https://cf.geekdo-images.com/hXdfAhgZ8OeyWLunt36wlw__micro/img/qdkWYsmTq_dyuJU5YCVCZMQrkAI=/fit-in/64x64/filters:strip_icc()/pic3578101.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname92">
# <div id="status_objectname92"></div>
# <div id="results_objectname92" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/170042/raiders-north-sea">Raiders of the North Sea</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Gather your Viking crew in order to plunder seas and lands for glory!
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.546		</td>
# <td align="center" class="collection_bggrating">
# 			7.77		</td>
# <td align="center" class="collection_bggrating">
# 			19037		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_170042_textwithprices__"></div>
# 																	[<a href="/boardgame/170042/raiders-north-sea/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="93"></a>			93
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/146021/eldritch-horror"><img alt="Board Game: Eldritch Horror" src="https://cf.geekdo-images.com/oxdsZKIX5_3ovDo38EIaeg__micro/img/gx6OxFzIkjvAvXPs8CDcucwwhak=/fit-in/64x64/filters:strip_icc()/pic1872452.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname93">
# <div id="status_objectname93"></div>
# <div id="results_objectname93" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/146021/eldritch-horror">Eldritch Horror</a>
# <span class="smallerfont dull">(2013)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			An unknown Elder God approaches the world—and you must solve mysteries to stop it.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.545		</td>
# <td align="center" class="collection_bggrating">
# 			7.78		</td>
# <td align="center" class="collection_bggrating">
# 			32064		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_146021_textwithprices__"></div>
# 																	[<a href="/boardgame/146021/eldritch-horror/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="94"></a>			94
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/172386/mombasa"><img alt="Board Game: Mombasa" src="https://cf.geekdo-images.com/VceWk5QVkgIp6rWDl5qHKQ__micro/img/nHZMadoKR1T5fSg9V6rkR3e39M0=/fit-in/64x64/filters:strip_icc()/pic2611318.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname94">
# <div id="status_objectname94"></div>
# <div id="results_objectname94" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/172386/mombasa">Mombasa</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Acquire shares of unique companies and propagate their trading posts to rake in cash.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.545		</td>
# <td align="center" class="collection_bggrating">
# 			7.87		</td>
# <td align="center" class="collection_bggrating">
# 			11842		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_172386_textwithprices__"></div>
# 																	[<a href="/boardgame/172386/mombasa/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="95"></a>			95
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/295947/cascadia"><img alt="Board Game: Cascadia" src="https://cf.geekdo-images.com/MjeJZfulbsM1DSV3DrGJYA__micro/img/x2BDobiHVhQHl7LhBimeU8L1ko4=/fit-in/64x64/filters:strip_icc()/pic5100691.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname95">
# <div id="status_objectname95"></div>
# <div id="results_objectname95" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/295947/cascadia">Cascadia</a>
# <span class="smallerfont dull">(2021)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Create the most harmonious ecosystem as you puzzle together habitats and wildlife.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.532		</td>
# <td align="center" class="collection_bggrating">
# 			8.08		</td>
# <td align="center" class="collection_bggrating">
# 			7239		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_295947_textwithprices__"></div>
# 																	[<a href="/boardgame/295947/cascadia/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="96"></a>			96
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/203993/lorenzo-il-magnifico"><img alt="Board Game: Lorenzo il Magnifico" src="https://cf.geekdo-images.com/8G6GkImjt0F_L5aYb8fmtQ__micro/img/kDuDqsd-uzh0n9aqlsEoHXZbgfY=/fit-in/64x64/filters:strip_icc()/pic3175535.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname96">
# <div id="status_objectname96"></div>
# <div id="results_objectname96" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/203993/lorenzo-il-magnifico">Lorenzo il Magnifico</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Avoid excommunication and lead your family to power during the Italian Renaissance.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.530		</td>
# <td align="center" class="collection_bggrating">
# 			7.88		</td>
# <td align="center" class="collection_bggrating">
# 			11147		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_203993_textwithprices__"></div>
# 																	[<a href="/boardgame/203993/lorenzo-il-magnifico/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="97"></a>			97
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/205896/rising-sun"><img alt="Board Game: Rising Sun" src="https://cf.geekdo-images.com/iwevA6XmiNLHn1QnGUucqw__micro/img/CGB3Ihk0wWICh8wG6_Wp2pbGoCk=/fit-in/64x64/filters:strip_icc()/pic3880340.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname97">
# <div id="status_objectname97"></div>
# <div id="results_objectname97" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/205896/rising-sun">Rising Sun</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Lead your clan to victory through negotiation, combat, monsters and favors from Kami.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.528		</td>
# <td align="center" class="collection_bggrating">
# 			7.82		</td>
# <td align="center" class="collection_bggrating">
# 			17990		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_205896_textwithprices__"></div>
# 																	[<a href="/boardgame/205896/rising-sun/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="98"></a>			98
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/42/tigris-euphrates"><img alt="Board Game: Tigris &amp; Euphrates" src="https://cf.geekdo-images.com/soAzNVWglCdVBacNjoCTJw__micro/img/7MXTV2Z2rBL40blbo6F8e1RBeRo=/fit-in/64x64/filters:strip_icc()/pic2338267.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname98">
# <div id="status_objectname98"></div>
# <div id="results_objectname98" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/42/tigris-euphrates">Tigris &amp; Euphrates</a>
# <span class="smallerfont dull">(1997)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Keep your Mesopotamian civilisation in perfect balance through revolutions and wars.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.527		</td>
# <td align="center" class="collection_bggrating">
# 			7.70		</td>
# <td align="center" class="collection_bggrating">
# 			26491		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_42_textwithprices__"></div>
# 																	[<a href="/boardgame/42/tigris-euphrates/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="99"></a>			99
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/281259/isle-cats"><img alt="Board Game: The Isle of Cats" src="https://cf.geekdo-images.com/AuAheDzhkLufiZFE9JaRNA__micro/img/rx1j8qFjOrmsWHaQhseRKppXKSA=/fit-in/64x64/filters:strip_icc()/pic4781085.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname99">
# <div id="status_objectname99"></div>
# <div id="results_objectname99" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/281259/isle-cats">The Isle of Cats</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Rescue as many island cats as you can before Lord Vesh comes to destroy their home.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.526		</td>
# <td align="center" class="collection_bggrating">
# 			7.88		</td>
# <td align="center" class="collection_bggrating">
# 			12784		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_281259_textwithprices__"></div>
# 																	[<a href="/boardgame/281259/isle-cats/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="100"></a>			100
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/163412/patchwork"><img alt="Board Game: Patchwork" src="https://cf.geekdo-images.com/wLW7pFn0--20lEizEz5p3A__micro/img/HGRTd0C4poFciUwMZzBt6On1R3Y=/fit-in/64x64/filters:strip_icc()/pic2270442.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname100">
# <div id="status_objectname100"></div>
# <div id="results_objectname100" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/163412/patchwork">Patchwork</a>
# <span class="smallerfont dull">(2014)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Piece together a quilt and leave no holes to become the button master.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.526		</td>
# <td align="center" class="collection_bggrating">
# 			7.63		</td>
# <td align="center" class="collection_bggrating">
# 			54050		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_163412_textwithprices__"></div>
# 																	[<a href="/boardgame/163412/patchwork/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# </table>
# </div>
# </div>
# <p align="right"><b>1</b> , <a href="/browse/boardgame/page/2" target="_self" title="page 2">2</a> , <a href="/browse/boardgame/page/3" target="_self" title="page 3">3</a> , <a href="/browse/boardgame/page/4" target="_self" title="page 4">4</a> , <a href="/browse/boardgame/page/5" target="_self" title="page 5">5</a>  <a href="/browse/boardgame/page/2" target="_self" title="next page"><b>Next »</b></a>  <a href="/browse/boardgame/page/1353" target="_self" title="last page">[1353]</a></p>
# <div id="legacy_modal"></div>
# </div>
# </div>
# </div>
# <div class="global-body-content-secondary">
# </div>
# </div>
# <div class="global-body-ad" hide-ad-block="blockskyscraper">
# <div class="advertisement advertisement-top">
# <div class="center-block advertisement-adsense-skyscraper" ng-dfp-ad="dfp-skyscraper"></div>
# </div>
# </div>
# </div>
# </main>
# <geekoutput-footer></geekoutput-footer>
# </div>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-104725-1"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
# 	gtag('consent', 'default', {
# 		'ad_storage': 'denied',
# 		'analytics_storage': 'denied',
# 		'personalization_storage': 'denied',
# 		'wait_for_update': 3000
# 	});
# 	gtag('config', 'UA-104725-1', {
# 		'cookie_domain': 'boardgamegeek.com'
# 	});
# </script>
# <script>
# 	gtag( 'event', 'page_view' );
# </script>
# </body>
# </html>

# %%
# extract the data from the web page     
tables = soup.find_all('table')
table = tables[0]

print(table) #verify table was pulled
# Out:
# <table cellpadding="0" cellspacing="1" class="collection_table" id="collectionitems" width="100%">
# <tr>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=rank&amp;sortdir=desc">Board Game Rank<img alt="ascending sort" border="0" hspace="5" src="https://cf.geekdo-static.com/images/collection/arrow_up.gif"/></a>
# </th>
# <th class="collection_thumbnail">
# <span class="sr-only">Thumbnail image</span>
# </th>
# <th class="collection_title">
# <a href="/browse/boardgame?sort=title">Title</a>
# </th>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=bggrating">Geek Rating</a>
# </th>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=avgrating">Avg Rating</a>
# </th>
# <th class="collection_bggrating">
# <a href="/browse/boardgame?sort=numvoters">Num Voters</a>
# </th>
# <th class="collection_shop">
# 			Shop
# 		</th>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="1"></a>			1
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/174430/gloomhaven"><img alt="Board Game: Gloomhaven" src="https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__micro/img/sQyh47ClBO3d5sxPm73hMvM-JV4=/fit-in/64x64/filters:strip_icc()/pic2437871.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname1">
# <div id="status_objectname1"></div>
# <div id="results_objectname1" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/174430/gloomhaven">Gloomhaven</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Vanquish monsters with strategic cardplay. Fulfill your quest to leave your legacy!
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.499		</td>
# <td align="center" class="collection_bggrating">
# 			8.73		</td>
# <td align="center" class="collection_bggrating">
# 			49467		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_174430_textwithprices__"></div>
# 																	[<a href="/boardgame/174430/gloomhaven/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="2"></a>			2
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/161936/pandemic-legacy-season-1"><img alt="Board Game: Pandemic Legacy: Season 1" src="https://cf.geekdo-images.com/-Qer2BBPG7qGGDu6KcVDIw__micro/img/n6-sXYD6XXZoqIxq4P6AG7VPCuA=/fit-in/64x64/filters:strip_icc()/pic2452831.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname2">
# <div id="status_objectname2"></div>
# <div id="results_objectname2" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/161936/pandemic-legacy-season-1">Pandemic Legacy: Season 1</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Mutating diseases are spreading around the world - can your team save humanity?
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.437		</td>
# <td align="center" class="collection_bggrating">
# 			8.59		</td>
# <td align="center" class="collection_bggrating">
# 			46063		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_161936_textwithprices__"></div>
# 																	[<a href="/boardgame/161936/pandemic-legacy-season-1/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="3"></a>			3
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/224517/brass-birmingham"><img alt="Board Game: Brass: Birmingham" src="https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__micro/img/4Od3GYCiqptga0VbmyumPbJlBsU=/fit-in/64x64/filters:strip_icc()/pic3490053.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname3">
# <div id="status_objectname3"></div>
# <div id="results_objectname3" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/224517/brass-birmingham">Brass: Birmingham</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build networks, grow industries, and navigate the world of the Industrial Revolution.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.422		</td>
# <td align="center" class="collection_bggrating">
# 			8.66		</td>
# <td align="center" class="collection_bggrating">
# 			27313		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_224517_textwithprices__"></div>
# 																	[<a href="/boardgame/224517/brass-birmingham/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="4"></a>			4
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/167791/terraforming-mars"><img alt="Board Game: Terraforming Mars" src="https://cf.geekdo-images.com/wg9oOLcsKvDesSUdZQ4rxw__micro/img/LUkXZhd1TO80eCiXMD3-KfnzA6k=/fit-in/64x64/filters:strip_icc()/pic3536616.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname4">
# <div id="status_objectname4"></div>
# <div id="results_objectname4" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/167791/terraforming-mars">Terraforming Mars</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Compete with rival CEOs to make Mars habitable and build your corporate empire.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.269		</td>
# <td align="center" class="collection_bggrating">
# 			8.41		</td>
# <td align="center" class="collection_bggrating">
# 			77092		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_167791_textwithprices__"></div>
# 																	[<a href="/boardgame/167791/terraforming-mars/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="5"></a>			5
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/291457/gloomhaven-jaws-lion"><img alt="Board Game: Gloomhaven: Jaws of the Lion" src="https://cf.geekdo-images.com/_HhIdavYW-hid20Iq3hhmg__micro/img/OdKjWiFsNvQAfJfXXSITttiozWE=/fit-in/64x64/filters:strip_icc()/pic5055631.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname5">
# <div id="status_objectname5"></div>
# <div id="results_objectname5" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/291457/gloomhaven-jaws-lion">Gloomhaven: Jaws of the Lion</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Vanquish monsters with strategic cardplay in a 25-scenario Gloomhaven campaign.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.267		</td>
# <td align="center" class="collection_bggrating">
# 			8.65		</td>
# <td align="center" class="collection_bggrating">
# 			18306		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_291457_textwithprices__"></div>
# 																	[<a href="/boardgame/291457/gloomhaven-jaws-lion/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="6"></a>			6
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/233078/twilight-imperium-fourth-edition"><img alt="Board Game: Twilight Imperium: Fourth Edition" src="https://cf.geekdo-images.com/_Ppn5lssO5OaildSE-FgFA__micro/img/2gymaKs35_2yj7eyyA6cYyVmd9c=/fit-in/64x64/filters:strip_icc()/pic3727516.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname6">
# <div id="status_objectname6"></div>
# <div id="results_objectname6" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/233078/twilight-imperium-fourth-edition">Twilight Imperium: Fourth Edition</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build an intergalactic empire through trade, research, conquest and grand politics.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.256		</td>
# <td align="center" class="collection_bggrating">
# 			8.66		</td>
# <td align="center" class="collection_bggrating">
# 			16792		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_233078_textwithprices__"></div>
# 																	[<a href="/boardgame/233078/twilight-imperium-fourth-edition/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="7"></a>			7
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/220308/gaia-project"><img alt="Board Game: Gaia Project" src="https://cf.geekdo-images.com/hGWFm3hbMlCDsfCsauOQ4g__micro/img/odWj2bEnZi9dEcQQrOtYj1e0QLE=/fit-in/64x64/filters:strip_icc()/pic5375625.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname7">
# <div id="status_objectname7"></div>
# <div id="results_objectname7" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/220308/gaia-project">Gaia Project</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Expand, research, upgrade, and settle the galaxy with one of 14 alien species.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.173		</td>
# <td align="center" class="collection_bggrating">
# 			8.47		</td>
# <td align="center" class="collection_bggrating">
# 			20213		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_220308_textwithprices__"></div>
# 																	[<a href="/boardgame/220308/gaia-project/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="8"></a>			8
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/187645/star-wars-rebellion"><img alt="Board Game: Star Wars: Rebellion" src="https://cf.geekdo-images.com/7SrPNGBKg9IIsP4UQpOi8g__micro/img/nEvTiCkWpT-ymH4bstc9c335TtQ=/fit-in/64x64/filters:strip_icc()/pic4325841.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname8">
# <div id="status_objectname8"></div>
# <div id="results_objectname8" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/187645/star-wars-rebellion">Star Wars: Rebellion</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Strike from your hidden base as the Rebels—or find and destroy it as the Empire.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.169		</td>
# <td align="center" class="collection_bggrating">
# 			8.42		</td>
# <td align="center" class="collection_bggrating">
# 			26313		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_187645_textwithprices__"></div>
# 																	[<a href="/boardgame/187645/star-wars-rebellion/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="9"></a>			9
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/162886/spirit-island"><img alt="Board Game: Spirit Island" src="https://cf.geekdo-images.com/a13ieMPP2s0KEaKNYmtH5w__micro/img/HQaHfx5cy6wJtZBMZCbVeNbfdy8=/fit-in/64x64/filters:strip_icc()/pic3615739.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname9">
# <div id="status_objectname9"></div>
# <div id="results_objectname9" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/162886/spirit-island">Spirit Island</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Island Spirits join forces using elemental powers to defend their home from invaders.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.142		</td>
# <td align="center" class="collection_bggrating">
# 			8.36		</td>
# <td align="center" class="collection_bggrating">
# 			34294		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_162886_textwithprices__"></div>
# 																	[<a href="/boardgame/162886/spirit-island/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="10"></a>			10
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/115746/war-ring-second-edition"><img alt="Board Game: War of the Ring: Second Edition" src="https://cf.geekdo-images.com/ImPgGag98W6gpV1KV812aA__micro/img/NT-Av_3kdYUcwuti5ocmIQXow3g=/fit-in/64x64/filters:strip_icc()/pic1215633.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname10">
# <div id="status_objectname10"></div>
# <div id="results_objectname10" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/115746/war-ring-second-edition">War of the Ring: Second Edition</a>
# <span class="smallerfont dull">(2011)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			The Fellowship and the Free Peoples clash with Sauron over the fate of Middle-Earth.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.141		</td>
# <td align="center" class="collection_bggrating">
# 			8.52		</td>
# <td align="center" class="collection_bggrating">
# 			16056		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_115746_textwithprices__"></div>
# 																	[<a href="/boardgame/115746/war-ring-second-edition/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="11"></a>			11
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/182028/through-ages-new-story-civilization"><img alt="Board Game: Through the Ages: A New Story of Civilization" src="https://cf.geekdo-images.com/fVwPntkJKgaEo0rIC0RwpA__micro/img/77dZJpqtydc8TTecl0ReGF7iAVw=/fit-in/64x64/filters:strip_icc()/pic2663291.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname11">
# <div id="status_objectname11"></div>
# <div id="results_objectname11" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/182028/through-ages-new-story-civilization">Through the Ages: A New Story of Civilization</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Rewrite history as you build up your civilization in this epic card drafting game!
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.141		</td>
# <td align="center" class="collection_bggrating">
# 			8.37		</td>
# <td align="center" class="collection_bggrating">
# 			26312		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_182028_textwithprices__"></div>
# 																	[<a href="/boardgame/182028/through-ages-new-story-civilization/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="12"></a>			12
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/193738/great-western-trail"><img alt="Board Game: Great Western Trail" src="https://cf.geekdo-images.com/u1l0gH7sb_vnvDvoO_QHqA__micro/img/xeShpQfbj4L1id-ItJbfIYVzgyA=/fit-in/64x64/filters:strip_icc()/pic4887376.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname12">
# <div id="status_objectname12"></div>
# <div id="results_objectname12" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/193738/great-western-trail">Great Western Trail</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Use strategic outposts and navigate danger as you herd your cattle to Kansas City.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.120		</td>
# <td align="center" class="collection_bggrating">
# 			8.29		</td>
# <td align="center" class="collection_bggrating">
# 			33958		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_193738_textwithprices__"></div>
# 																	[<a href="/boardgame/193738/great-western-trail/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="13"></a>			13
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/12333/twilight-struggle"><img alt="Board Game: Twilight Struggle" src="https://cf.geekdo-images.com/pNCiUUphnoeWOYfsWq0kng__micro/img/ZlfJiIATIt5MY7xWSMzFmdygaa0=/fit-in/64x64/filters:strip_icc()/pic3530661.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname13">
# <div id="status_objectname13"></div>
# <div id="results_objectname13" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/12333/twilight-struggle">Twilight Struggle</a>
# <span class="smallerfont dull">(2005)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Relive the Cold War and rewrite history in an epic clash between the USA and USSR.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.110		</td>
# <td align="center" class="collection_bggrating">
# 			8.28		</td>
# <td align="center" class="collection_bggrating">
# 			43671		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_12333_textwithprices__"></div>
# 																	[<a href="/boardgame/12333/twilight-struggle/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="14"></a>			14
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/169786/scythe"><img alt="Board Game: Scythe" src="https://cf.geekdo-images.com/7k_nOxpO9OGIjhLq2BUZdA__micro/img/ETplc22GdhlN5u0mppcDxSP8LVk=/fit-in/64x64/filters:strip_icc()/pic3163924.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname14">
# <div id="status_objectname14"></div>
# <div id="results_objectname14" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/169786/scythe">Scythe</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Five factions vie for dominance in a war-torn, mech-filled, dieselpunk 1920s Europe.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.059		</td>
# <td align="center" class="collection_bggrating">
# 			8.21		</td>
# <td align="center" class="collection_bggrating">
# 			66884		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_169786_textwithprices__"></div>
# 																	[<a href="/boardgame/169786/scythe/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="15"></a>			15
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/316554/dune-imperium"><img alt="Board Game: Dune: Imperium" src="https://cf.geekdo-images.com/PhjygpWSo-0labGrPBMyyg__micro/img/mfU7-dEFnVyXJrF-BWAO0buexao=/fit-in/64x64/filters:strip_icc()/pic5666597.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname15">
# <div id="status_objectname15"></div>
# <div id="results_objectname15" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/316554/dune-imperium">Dune: Imperium</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Influence, intrigue, and combat in the universe of Dune.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.018		</td>
# <td align="center" class="collection_bggrating">
# 			8.33		</td>
# <td align="center" class="collection_bggrating">
# 			18424		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_316554_textwithprices__"></div>
# 																	[<a href="/boardgame/316554/dune-imperium/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="16"></a>			16
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/84876/castles-burgundy"><img alt="Board Game: The Castles of Burgundy" src="https://cf.geekdo-images.com/5CFwjd8zTcGYVUnkXh04hw__micro/img/N1VrEUaW6bmwnqbZfi2nRScwGxM=/fit-in/64x64/filters:strip_icc()/pic1176894.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname16">
# <div id="status_objectname16"></div>
# <div id="results_objectname16" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/84876/castles-burgundy">The Castles of Burgundy</a>
# <span class="smallerfont dull">(2011)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Plan, trade, and build your Burgundian estate to prosperity and prominence.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			8.006		</td>
# <td align="center" class="collection_bggrating">
# 			8.13		</td>
# <td align="center" class="collection_bggrating">
# 			51864		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_84876_textwithprices__"></div>
# 																	[<a href="/boardgame/84876/castles-burgundy/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="17"></a>			17
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/167355/nemesis"><img alt="Board Game: Nemesis" src="https://cf.geekdo-images.com/tAqLpWxQ0Oo3GaPP3MER1g__micro/img/tivhH093LwCowK-_S7bVF_xha34=/fit-in/64x64/filters:strip_icc()/pic5073276.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname17">
# <div id="status_objectname17"></div>
# <div id="results_objectname17" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/167355/nemesis">Nemesis</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Survive an alien-infested spaceship but beware of other players and their agendas.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.987		</td>
# <td align="center" class="collection_bggrating">
# 			8.38		</td>
# <td align="center" class="collection_bggrating">
# 			19175		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_167355_textwithprices__"></div>
# 																	[<a href="/boardgame/167355/nemesis/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="18"></a>			18
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/173346/7-wonders-duel"><img alt="Board Game: 7 Wonders Duel" src="https://cf.geekdo-images.com/WzNs1mA_o22ZWTR8fkLP2g__micro/img/xh3isprMbt_FCg9vs3w_ifv-JXY=/fit-in/64x64/filters:strip_icc()/pic3376065.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname18">
# <div id="status_objectname18"></div>
# <div id="results_objectname18" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/173346/7-wonders-duel">7 Wonders Duel</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Science? Military? What will you draft to win this head-to-head version of 7 Wonders?
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.983		</td>
# <td align="center" class="collection_bggrating">
# 			8.11		</td>
# <td align="center" class="collection_bggrating">
# 			72475		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_173346_textwithprices__"></div>
# 																	[<a href="/boardgame/173346/7-wonders-duel/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="19"></a>			19
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/124361/concordia"><img alt="Board Game: Concordia" src="https://cf.geekdo-images.com/CzwSm8i7tkLz6cBnrILZBg__micro/img/FQyxREkHBn7yTbGmBg7c44eLgaM=/fit-in/64x64/filters:strip_icc()/pic3453267.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname19">
# <div id="status_objectname19"></div>
# <div id="results_objectname19" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/124361/concordia">Concordia</a>
# <span class="smallerfont dull">(2013)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Lead your Roman dynasty and build the greatest trading empire in the Mediterranean.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.968		</td>
# <td align="center" class="collection_bggrating">
# 			8.12		</td>
# <td align="center" class="collection_bggrating">
# 			32560		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_124361_textwithprices__"></div>
# 																	[<a href="/boardgame/124361/concordia/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="20"></a>			20
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/28720/brass-lancashire"><img alt="Board Game: Brass: Lancashire" src="https://cf.geekdo-images.com/tHVtPzu82mBpeQbbZkV6EA__micro/img/jM8d5Q5btvJmcWQN_px-A-nlueI=/fit-in/64x64/filters:strip_icc()/pic3469216.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname20">
# <div id="status_objectname20"></div>
# <div id="results_objectname20" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/28720/brass-lancashire">Brass: Lancashire</a>
# <span class="smallerfont dull">(2007)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Test your economic mettle as you build and network in the Industrial Revolution.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.966		</td>
# <td align="center" class="collection_bggrating">
# 			8.18		</td>
# <td align="center" class="collection_bggrating">
# 			21314		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_28720_textwithprices__"></div>
# 																	[<a href="/boardgame/28720/brass-lancashire/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="21"></a>			21
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/120677/terra-mystica"><img alt="Board Game: Terra Mystica" src="https://cf.geekdo-images.com/bre12I1YiXkZr7elvriz4A__micro/img/SAwaBrDhHbGuq6dFY-ok95qFMcU=/fit-in/64x64/filters:strip_icc()/pic5375624.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname21">
# <div id="status_objectname21"></div>
# <div id="results_objectname21" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/120677/terra-mystica">Terra Mystica</a>
# <span class="smallerfont dull">(2012)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Play fantastical factions.  Expand your influence by terraforming and joining cults.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.958		</td>
# <td align="center" class="collection_bggrating">
# 			8.12		</td>
# <td align="center" class="collection_bggrating">
# 			42539		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_120677_textwithprices__"></div>
# 																	[<a href="/boardgame/120677/terra-mystica/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="22"></a>			22
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/177736/feast-odin"><img alt="Board Game: A Feast for Odin" src="https://cf.geekdo-images.com/s9oGMCo1fcfV4Dk3EnqLZw__micro/img/JCrcuFDrjVQ64uLbqpH-Pmg6XsU=/fit-in/64x64/filters:strip_icc()/pic3146943.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname22">
# <div id="status_objectname22"></div>
# <div id="results_objectname22" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/177736/feast-odin">A Feast for Odin</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Puzzle together the life of a Viking village as you hunt, farm, craft, and explore.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.953		</td>
# <td align="center" class="collection_bggrating">
# 			8.20		</td>
# <td align="center" class="collection_bggrating">
# 			21370		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_177736_textwithprices__"></div>
# 																	[<a href="/boardgame/177736/feast-odin/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="23"></a>			23
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/266192/wingspan"><img alt="Board Game: Wingspan" src="https://cf.geekdo-images.com/yLZJCVLlIx4c7eJEWUNJ7w__micro/img/5ZaRePVhfelfofF7T_OC1e0gUCw=/fit-in/64x64/filters:strip_icc()/pic4458123.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname23">
# <div id="status_objectname23"></div>
# <div id="results_objectname23" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/266192/wingspan">Wingspan</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Attract a beautiful and diverse collection of birds to your wildlife reserve.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.943		</td>
# <td align="center" class="collection_bggrating">
# 			8.10		</td>
# <td align="center" class="collection_bggrating">
# 			60195		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_266192_textwithprices__"></div>
# 																	[<a href="/boardgame/266192/wingspan/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="24"></a>			24
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/205637/arkham-horror-card-game"><img alt="Board Game: Arkham Horror: The Card Game" src="https://cf.geekdo-images.com/RdCWCXPnBGSxoOhk5Hkq_g__micro/img/TVx3_34ywzwURntW1WMKBx6ZeCg=/fit-in/64x64/filters:strip_icc()/pic6530423.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname24">
# <div id="status_objectname24"></div>
# <div id="results_objectname24" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/205637/arkham-horror-card-game">Arkham Horror: The Card Game</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Investigate the horrors of Arkham while courting cosmic doom.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.926		</td>
# <td align="center" class="collection_bggrating">
# 			8.16		</td>
# <td align="center" class="collection_bggrating">
# 			34490		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_205637_textwithprices__"></div>
# 																	[<a href="/boardgame/205637/arkham-horror-card-game/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="25"></a>			25
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/183394/viticulture-essential-edition"><img alt="Board Game: Viticulture Essential Edition" src="https://cf.geekdo-images.com/l_PRU2lVlX9seScRFcvFlA__micro/img/3EqHlTkNSnZNFHVaAeFSpzfzuIQ=/fit-in/64x64/filters:strip_icc()/pic6500949.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname25">
# <div id="status_objectname25"></div>
# <div id="results_objectname25" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/183394/viticulture-essential-edition">Viticulture Essential Edition</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Create the most prosperous winery in Italy from the Tuscan vineyard you've inherited.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.891		</td>
# <td align="center" class="collection_bggrating">
# 			8.05		</td>
# <td align="center" class="collection_bggrating">
# 			36505		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_183394_textwithprices__"></div>
# 																	[<a href="/boardgame/183394/viticulture-essential-edition/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="26"></a>			26
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/237182/root"><img alt="Board Game: Root" src="https://cf.geekdo-images.com/JUAUWaVUzeBgzirhZNmHHw__micro/img/tdHLiMYfi-KTy89sGBGZVeE9ts0=/fit-in/64x64/filters:strip_icc()/pic4254509.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname26">
# <div id="status_objectname26"></div>
# <div id="results_objectname26" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/237182/root">Root</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Decide the fate of the forest as woodland factions fight for contrasting goals.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.889		</td>
# <td align="center" class="collection_bggrating">
# 			8.10		</td>
# <td align="center" class="collection_bggrating">
# 			33655		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_237182_textwithprices__"></div>
# 																	[<a href="/boardgame/237182/root/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="27"></a>			27
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/164928/orleans"><img alt="Board Game: Orléans" src="https://cf.geekdo-images.com/nagl1li6kYt9elV9jbfVQw__micro/img/hUKCvnqgFvTl0aOMd8FLkgCObT0=/fit-in/64x64/filters:strip_icc()/pic6228507.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname27">
# <div id="status_objectname27"></div>
# <div id="results_objectname27" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/164928/orleans">Orléans</a>
# <span class="smallerfont dull">(2014)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Craftsmen, scholars &amp; monks can help you reign supreme—but who will turn up to help?
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.884		</td>
# <td align="center" class="collection_bggrating">
# 			8.07		</td>
# <td align="center" class="collection_bggrating">
# 			25390		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_164928_textwithprices__"></div>
# 																	[<a href="/boardgame/164928/orleans/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="28"></a>			28
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/199792/everdell"><img alt="Board Game: Everdell" src="https://cf.geekdo-images.com/fjE7V5LNq31yVEW_yuqI-Q__micro/img/TAgkPCJdNAIHZfn1BE1DXadBL9g=/fit-in/64x64/filters:strip_icc()/pic3918905.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname28">
# <div id="status_objectname28"></div>
# <div id="results_objectname28" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/199792/everdell">Everdell</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Use resources to build a village of critters and constructions in this woodland game.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.882		</td>
# <td align="center" class="collection_bggrating">
# 			8.09		</td>
# <td align="center" class="collection_bggrating">
# 			31949		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_199792_textwithprices__"></div>
# 																	[<a href="/boardgame/199792/everdell/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="29"></a>			29
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/266507/clank-legacy-acquisitions-incorporated"><img alt="Board Game: Clank! Legacy: Acquisitions Incorporated" src="https://cf.geekdo-images.com/hc2NDafu5c24iLJh_IZmyg__micro/img/v2WzacDprYF837E6h9O2WuFFmpw=/fit-in/64x64/filters:strip_icc()/pic4885780.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname29">
# <div id="status_objectname29"></div>
# <div id="results_objectname29" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/266507/clank-legacy-acquisitions-incorporated">Clank!: Legacy – Acquisitions Incorporated</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			"Go forth, be bold, and ACQUIRE!" in this campaign version of "Clank!"
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.876		</td>
# <td align="center" class="collection_bggrating">
# 			8.67		</td>
# <td align="center" class="collection_bggrating">
# 			5536		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_266507_textwithprices__"></div>
# 																	[<a href="/boardgame/266507/clank-legacy-acquisitions-incorporated/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="30"></a>			30
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/96848/mage-knight-board-game"><img alt="Board Game: Mage Knight Board Game" src="https://cf.geekdo-images.com/DUO2hz9AlLOH8p9ED-lCWg__micro/img/eXzdbUmCbIdMIVgiQ_QwS3YNOS4=/fit-in/64x64/filters:strip_icc()/pic1083380.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname30">
# <div id="status_objectname30"></div>
# <div id="results_objectname30" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/96848/mage-knight-board-game">Mage Knight Board Game</a>
# <span class="smallerfont dull">(2011)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build your hero’s spells, abilities, and artifacts as you explore &amp; conquer cities.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.875		</td>
# <td align="center" class="collection_bggrating">
# 			8.10		</td>
# <td align="center" class="collection_bggrating">
# 			29861		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_96848_textwithprices__"></div>
# 																	[<a href="/boardgame/96848/mage-knight-board-game/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="31"></a>			31
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/312484/lost-ruins-arnak"><img alt="Board Game: Lost Ruins of Arnak" src="https://cf.geekdo-images.com/6GqH14TJJhza86BX5HCLEQ__micro/img/2FKVaukjh9a-Kg9LWQuMSvLS34s=/fit-in/64x64/filters:strip_icc()/pic5674958.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname31">
# <div id="status_objectname31"></div>
# <div id="results_objectname31" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/312484/lost-ruins-arnak">Lost Ruins of Arnak</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Explore an island to find resources and discover the lost ruins of Arnak.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.862		</td>
# <td align="center" class="collection_bggrating">
# 			8.12		</td>
# <td align="center" class="collection_bggrating">
# 			20814		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_312484_textwithprices__"></div>
# 																	[<a href="/boardgame/312484/lost-ruins-arnak/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="32"></a>			32
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/246900/eclipse-second-dawn-galaxy"><img alt="Board Game: Eclipse: Second Dawn for the Galaxy" src="https://cf.geekdo-images.com/Oh3kHw6lweg6ru71Q16h2Q__micro/img/vhB59zFDq3Kul0xbr3api2selZs=/fit-in/64x64/filters:strip_icc()/pic5235277.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname32">
# <div id="status_objectname32"></div>
# <div id="results_objectname32" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/246900/eclipse-second-dawn-galaxy">Eclipse: Second Dawn for the Galaxy</a>
# <span class="smallerfont dull">(2020)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Build an interstellar civilization by exploration, research, conquest, and diplomacy.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.861		</td>
# <td align="center" class="collection_bggrating">
# 			8.65		</td>
# <td align="center" class="collection_bggrating">
# 			6317		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_246900_textwithprices__"></div>
# 																	[<a href="/boardgame/246900/eclipse-second-dawn-galaxy/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="33"></a>			33
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/175914/food-chain-magnate"><img alt="Board Game: Food Chain Magnate" src="https://cf.geekdo-images.com/Wtxml94LAXsIWQCxGPS63Q__micro/img/4Oucoa190njfSaNHr8YRIl6UnTU=/fit-in/64x64/filters:strip_icc()/pic2649434.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname33">
# <div id="status_objectname33"></div>
# <div id="results_objectname33" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/175914/food-chain-magnate">Food Chain Magnate</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Strategically hire and manage your workforce to outcompete rival fast food chains.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.834		</td>
# <td align="center" class="collection_bggrating">
# 			8.11		</td>
# <td align="center" class="collection_bggrating">
# 			15970		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_175914_textwithprices__"></div>
# 																	[<a href="/boardgame/175914/food-chain-magnate/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="34"></a>			34
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/3076/puerto-rico"><img alt="Board Game: Puerto Rico" src="https://cf.geekdo-images.com/QFiIRd2kimaMqTyWsX0aUg__micro/img/ggNIAA1GEadqvcY7Mvwb9_VEybU=/fit-in/64x64/filters:strip_icc()/pic158548.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname34">
# <div id="status_objectname34"></div>
# <div id="results_objectname34" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/3076/puerto-rico">Puerto Rico</a>
# <span class="smallerfont dull">(2002)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Ship goods, construct buildings, and choose roles that benefit you more than others.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.831		</td>
# <td align="center" class="collection_bggrating">
# 			7.96		</td>
# <td align="center" class="collection_bggrating">
# 			66141		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_3076_textwithprices__"></div>
# 																	[<a href="/boardgame/3076/puerto-rico/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="35"></a>			35
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/102794/caverna-cave-farmers"><img alt="Board Game: Caverna: The Cave Farmers" src="https://cf.geekdo-images.com/rz22tqa5PCYvK9oDjIbvxg__micro/img/sog7ni3vUAAfvd66e6XW4iOca4I=/fit-in/64x64/filters:strip_icc()/pic1790789.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname35">
# <div id="status_objectname35"></div>
# <div id="results_objectname35" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/102794/caverna-cave-farmers">Caverna: The Cave Farmers</a>
# <span class="smallerfont dull">(2013)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			From a simple cave, expand your dwarven home through mining, agriculture, and more.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.820		</td>
# <td align="center" class="collection_bggrating">
# 			8.00		</td>
# <td align="center" class="collection_bggrating">
# 			30315		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_102794_textwithprices__"></div>
# 																	[<a href="/boardgame/102794/caverna-cave-farmers/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="36"></a>			36
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/170216/blood-rage"><img alt="Board Game: Blood Rage" src="https://cf.geekdo-images.com/HkZSJfQnZ3EpS214xtuplg__micro/img/7xdR1_OUo1ReAvYzhi7jBhFMHu0=/fit-in/64x64/filters:strip_icc()/pic2439223.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname36">
# <div id="status_objectname36"></div>
# <div id="results_objectname36" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/170216/blood-rage">Blood Rage</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Ragnarök has come! Secure your place in Valhalla in epic Viking battles.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.812		</td>
# <td align="center" class="collection_bggrating">
# 			7.99		</td>
# <td align="center" class="collection_bggrating">
# 			38798		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_170216_textwithprices__"></div>
# 																	[<a href="/boardgame/170216/blood-rage/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="37"></a>			37
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/285774/marvel-champions-card-game"><img alt="Board Game: Marvel Champions: The Card Game" src="https://cf.geekdo-images.com/kRvUgYiaOq07kC67ZK5UoQ__micro/img/4DLQr45lpVBfCkiy-kVwhl4z4vQ=/fit-in/64x64/filters:strip_icc()/pic4900321.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname37">
# <div id="status_objectname37"></div>
# <div id="results_objectname37" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/285774/marvel-champions-card-game">Marvel Champions: The Card Game</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Battle Marvel villains with unique teams of iconic heroes in this LCG.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.809		</td>
# <td align="center" class="collection_bggrating">
# 			8.20		</td>
# <td align="center" class="collection_bggrating">
# 			15336		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_285774_textwithprices__"></div>
# 																	[<a href="/boardgame/285774/marvel-champions-card-game/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="38"></a>			38
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/192135/too-many-bones"><img alt="Board Game: Too Many Bones" src="https://cf.geekdo-images.com/wKwRk0wYBcrtLAfgn4PCdg__micro/img/Q6VXZKoVSlMjTU7Vp8tn1tkcVzw=/fit-in/64x64/filters:strip_icc()/pic6624445.png"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname38">
# <div id="status_objectname38"></div>
# <div id="results_objectname38" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/192135/too-many-bones">Too Many Bones</a>
# <span class="smallerfont dull">(2017)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Toss gobs of unique dice in an epic adventure en route to a final boss showdown.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.806		</td>
# <td align="center" class="collection_bggrating">
# 			8.42		</td>
# <td align="center" class="collection_bggrating">
# 			8282		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_192135_textwithprices__"></div>
# 																	[<a href="/boardgame/192135/too-many-bones/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="39"></a>			39
# 					</td>
# <td class="collection_thumbnail">
# ...
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="88"></a>			88
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/12493/twilight-imperium-third-edition"><img alt="Board Game: Twilight Imperium: Third Edition" src="https://cf.geekdo-images.com/MHeQQrbauUVsvh2QF6PMog__micro/img/qq2rc5GmKHOr8Dpn5Q8di_FD6Cg=/fit-in/64x64/filters:strip_icc()/pic4128153.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname88">
# <div id="status_objectname88"></div>
# <div id="results_objectname88" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/12493/twilight-imperium-third-edition">Twilight Imperium: Third Edition</a>
# <span class="smallerfont dull">(2005)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Epic empire-building game of interstellar conflict, trade, and struggle for power.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.553		</td>
# <td align="center" class="collection_bggrating">
# 			7.82		</td>
# <td align="center" class="collection_bggrating">
# 			18721		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_12493_textwithprices__"></div>
# 																	[<a href="/boardgame/12493/twilight-imperium-third-edition/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="89"></a>			89
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/73439/troyes"><img alt="Board Game: Troyes" src="https://cf.geekdo-images.com/fBIe-aEPtJKC-ceNlspK6A__micro/img/6ZLZgf_o1omV4ijqi2OLJWK_GM0=/fit-in/64x64/filters:strip_icc()/pic750583.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname89">
# <div id="status_objectname89"></div>
# <div id="results_objectname89" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/73439/troyes">Troyes</a>
# <span class="smallerfont dull">(2010)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Defend the city and rise to power by influencing the merchants, knights and clergy.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.551		</td>
# <td align="center" class="collection_bggrating">
# 			7.75		</td>
# <td align="center" class="collection_bggrating">
# 			20601		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_73439_textwithprices__"></div>
# 																	[<a href="/boardgame/73439/troyes/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="90"></a>			90
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/40834/dominion-intrigue"><img alt="Board Game: Dominion: Intrigue" src="https://cf.geekdo-images.com/OGOmpi0GgwOwH2y28QgkuA__micro/img/VlsgqS2v915vSCwTPVWFVms0-TY=/fit-in/64x64/filters:strip_icc()/pic460011.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname90">
# <div id="status_objectname90"></div>
# <div id="results_objectname90" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/40834/dominion-intrigue">Dominion: Intrigue</a>
# <span class="smallerfont dull">(2009)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Enlist torturers, swindlers, and saboteurs to gain wealth and dominate the kingdom.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.549		</td>
# <td align="center" class="collection_bggrating">
# 			7.71		</td>
# <td align="center" class="collection_bggrating">
# 			31545		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_40834_textwithprices__"></div>
# 																	[<a href="/boardgame/40834/dominion-intrigue/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="91"></a>			91
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/269385/lord-rings-journeys-middle-earth"><img alt="Board Game: The Lord of the Rings: Journeys in Middle-Earth" src="https://cf.geekdo-images.com/1XA2-niwTBa0HEB7hOz3Dw__micro/img/yhbf5YV6KtavOaIVcFC1ZrDQE_0=/fit-in/64x64/filters:strip_icc()/pic4530974.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname91">
# <div id="status_objectname91"></div>
# <div id="results_objectname91" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/269385/lord-rings-journeys-middle-earth">The Lord of the Rings: Journeys in Middle-Earth</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Heroes explore Middle-earth, working together to combat evil in an epic campaign.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.548		</td>
# <td align="center" class="collection_bggrating">
# 			8.00		</td>
# <td align="center" class="collection_bggrating">
# 			11918		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_269385_textwithprices__"></div>
# 																	[<a href="/boardgame/269385/lord-rings-journeys-middle-earth/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="92"></a>			92
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/170042/raiders-north-sea"><img alt="Board Game: Raiders of the North Sea" src="https://cf.geekdo-images.com/hXdfAhgZ8OeyWLunt36wlw__micro/img/qdkWYsmTq_dyuJU5YCVCZMQrkAI=/fit-in/64x64/filters:strip_icc()/pic3578101.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname92">
# <div id="status_objectname92"></div>
# <div id="results_objectname92" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/170042/raiders-north-sea">Raiders of the North Sea</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Gather your Viking crew in order to plunder seas and lands for glory!
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.546		</td>
# <td align="center" class="collection_bggrating">
# 			7.77		</td>
# <td align="center" class="collection_bggrating">
# 			19037		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_170042_textwithprices__"></div>
# 																	[<a href="/boardgame/170042/raiders-north-sea/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="93"></a>			93
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/146021/eldritch-horror"><img alt="Board Game: Eldritch Horror" src="https://cf.geekdo-images.com/oxdsZKIX5_3ovDo38EIaeg__micro/img/gx6OxFzIkjvAvXPs8CDcucwwhak=/fit-in/64x64/filters:strip_icc()/pic1872452.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname93">
# <div id="status_objectname93"></div>
# <div id="results_objectname93" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/146021/eldritch-horror">Eldritch Horror</a>
# <span class="smallerfont dull">(2013)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			An unknown Elder God approaches the world—and you must solve mysteries to stop it.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.545		</td>
# <td align="center" class="collection_bggrating">
# 			7.78		</td>
# <td align="center" class="collection_bggrating">
# 			32064		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_146021_textwithprices__"></div>
# 																	[<a href="/boardgame/146021/eldritch-horror/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="94"></a>			94
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/172386/mombasa"><img alt="Board Game: Mombasa" src="https://cf.geekdo-images.com/VceWk5QVkgIp6rWDl5qHKQ__micro/img/nHZMadoKR1T5fSg9V6rkR3e39M0=/fit-in/64x64/filters:strip_icc()/pic2611318.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname94">
# <div id="status_objectname94"></div>
# <div id="results_objectname94" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/172386/mombasa">Mombasa</a>
# <span class="smallerfont dull">(2015)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Acquire shares of unique companies and propagate their trading posts to rake in cash.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.545		</td>
# <td align="center" class="collection_bggrating">
# 			7.87		</td>
# <td align="center" class="collection_bggrating">
# 			11842		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_172386_textwithprices__"></div>
# 																	[<a href="/boardgame/172386/mombasa/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="95"></a>			95
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/295947/cascadia"><img alt="Board Game: Cascadia" src="https://cf.geekdo-images.com/MjeJZfulbsM1DSV3DrGJYA__micro/img/x2BDobiHVhQHl7LhBimeU8L1ko4=/fit-in/64x64/filters:strip_icc()/pic5100691.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname95">
# <div id="status_objectname95"></div>
# <div id="results_objectname95" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/295947/cascadia">Cascadia</a>
# <span class="smallerfont dull">(2021)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Create the most harmonious ecosystem as you puzzle together habitats and wildlife.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.532		</td>
# <td align="center" class="collection_bggrating">
# 			8.08		</td>
# <td align="center" class="collection_bggrating">
# 			7239		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_295947_textwithprices__"></div>
# 																	[<a href="/boardgame/295947/cascadia/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="96"></a>			96
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/203993/lorenzo-il-magnifico"><img alt="Board Game: Lorenzo il Magnifico" src="https://cf.geekdo-images.com/8G6GkImjt0F_L5aYb8fmtQ__micro/img/kDuDqsd-uzh0n9aqlsEoHXZbgfY=/fit-in/64x64/filters:strip_icc()/pic3175535.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname96">
# <div id="status_objectname96"></div>
# <div id="results_objectname96" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/203993/lorenzo-il-magnifico">Lorenzo il Magnifico</a>
# <span class="smallerfont dull">(2016)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Avoid excommunication and lead your family to power during the Italian Renaissance.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.530		</td>
# <td align="center" class="collection_bggrating">
# 			7.88		</td>
# <td align="center" class="collection_bggrating">
# 			11147		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_203993_textwithprices__"></div>
# 																	[<a href="/boardgame/203993/lorenzo-il-magnifico/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="97"></a>			97
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/205896/rising-sun"><img alt="Board Game: Rising Sun" src="https://cf.geekdo-images.com/iwevA6XmiNLHn1QnGUucqw__micro/img/CGB3Ihk0wWICh8wG6_Wp2pbGoCk=/fit-in/64x64/filters:strip_icc()/pic3880340.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname97">
# <div id="status_objectname97"></div>
# <div id="results_objectname97" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/205896/rising-sun">Rising Sun</a>
# <span class="smallerfont dull">(2018)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Lead your clan to victory through negotiation, combat, monsters and favors from Kami.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.528		</td>
# <td align="center" class="collection_bggrating">
# 			7.82		</td>
# <td align="center" class="collection_bggrating">
# 			17990		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_205896_textwithprices__"></div>
# 																	[<a href="/boardgame/205896/rising-sun/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="98"></a>			98
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/42/tigris-euphrates"><img alt="Board Game: Tigris &amp; Euphrates" src="https://cf.geekdo-images.com/soAzNVWglCdVBacNjoCTJw__micro/img/7MXTV2Z2rBL40blbo6F8e1RBeRo=/fit-in/64x64/filters:strip_icc()/pic2338267.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname98">
# <div id="status_objectname98"></div>
# <div id="results_objectname98" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/42/tigris-euphrates">Tigris &amp; Euphrates</a>
# <span class="smallerfont dull">(1997)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Keep your Mesopotamian civilisation in perfect balance through revolutions and wars.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.527		</td>
# <td align="center" class="collection_bggrating">
# 			7.70		</td>
# <td align="center" class="collection_bggrating">
# 			26491		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_42_textwithprices__"></div>
# 																	[<a href="/boardgame/42/tigris-euphrates/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="99"></a>			99
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/281259/isle-cats"><img alt="Board Game: The Isle of Cats" src="https://cf.geekdo-images.com/AuAheDzhkLufiZFE9JaRNA__micro/img/rx1j8qFjOrmsWHaQhseRKppXKSA=/fit-in/64x64/filters:strip_icc()/pic4781085.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname99">
# <div id="status_objectname99"></div>
# <div id="results_objectname99" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/281259/isle-cats">The Isle of Cats</a>
# <span class="smallerfont dull">(2019)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Rescue as many island cats as you can before Lord Vesh comes to destroy their home.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.526		</td>
# <td align="center" class="collection_bggrating">
# 			7.88		</td>
# <td align="center" class="collection_bggrating">
# 			12784		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_281259_textwithprices__"></div>
# 																	[<a href="/boardgame/281259/isle-cats/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# <tr id="row_">
# <td align="center" class="collection_rank">
# <a name="100"></a>			100
# 					</td>
# <td class="collection_thumbnail">
# <a href="/boardgame/163412/patchwork"><img alt="Board Game: Patchwork" src="https://cf.geekdo-images.com/wLW7pFn0--20lEizEz5p3A__micro/img/HGRTd0C4poFciUwMZzBt6On1R3Y=/fit-in/64x64/filters:strip_icc()/pic2270442.jpg"/></a>
# </td>
# <td class="collection_objectname browse" id="CEcell_objectname100">
# <div id="status_objectname100"></div>
# <div id="results_objectname100" onclick="" style="z-index:1000;">
# <a class="primary" href="/boardgame/163412/patchwork">Patchwork</a>
# <span class="smallerfont dull">(2014)</span>
# </div>
# <p class="smallefont dull" style="margin: 2px 0 0 0;">
# 			Piece together a quilt and leave no holes to become the button master.
# 		</p>
# </td>
# <td align="center" class="collection_bggrating">
# 			7.526		</td>
# <td align="center" class="collection_bggrating">
# 			7.63		</td>
# <td align="center" class="collection_bggrating">
# 			54050		</td>
# <td class="collection_shop">
# <div class="aad" id="aad_thing_163412_textwithprices__"></div>
# 																	[<a href="/boardgame/163412/patchwork/marketplace/geekmarket">Shop</a>]
# 					</td>
# </tr>
# </table>

# %%
#pull all headers for the table
header = []
for th in table.tr.find_all('th'):
  header += [th.text]
  
header #verify headers were pulled
# Out:
# Out[4]: ['\nBoard Game Rank\n',
#  '\nThumbnail image\n',
#  '\nTitle\n',
#  '\nGeek Rating\n',
#  '\nAvg Rating\n',
#  '\nNum Voters\n',
#  '\n\t\t\tShop\n\t\t']

# %%
all_data = []
 
for table in tables:
  table_data = []
  for tr in table.find_all('tr', attrs={'id': 'row_'}):
    row_data = []
    for td in tr.find_all('td'):
      value = ''
      if td.a and td.a.img:
        value = td.a.img['src']
      else:
        value = td.text
      row_data += [value]
    table_data += [row_data]
  all_data += table_data
  
all_data #verify the table data was pulled
# Out:
# Out[5]: [['\n\t\t\t1\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__micro/img/sQyh47ClBO3d5sxPm73hMvM-JV4=/fit-in/64x64/filters:strip_icc()/pic2437871.jpg',
#   '\n\n\nGloomhaven\n(2017)\n\n\n\t\t\tVanquish monsters with strategic cardplay. Fulfill your quest to leave your legacy!\n\t\t\n',
#   '\n\t\t\t8.499\t\t',
#   '\n\t\t\t8.73\t\t',
#   '\n\t\t\t49467\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t2\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/-Qer2BBPG7qGGDu6KcVDIw__micro/img/n6-sXYD6XXZoqIxq4P6AG7VPCuA=/fit-in/64x64/filters:strip_icc()/pic2452831.png',
#   '\n\n\nPandemic Legacy: Season 1\n(2015)\n\n\n\t\t\tMutating diseases are spreading around the world - can your team save humanity?\n\t\t\n',
#   '\n\t\t\t8.437\t\t',
#   '\n\t\t\t8.59\t\t',
#   '\n\t\t\t46063\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t3\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__micro/img/4Od3GYCiqptga0VbmyumPbJlBsU=/fit-in/64x64/filters:strip_icc()/pic3490053.jpg',
#   '\n\n\nBrass: Birmingham\n(2018)\n\n\n\t\t\tBuild networks, grow industries, and navigate the world of the Industrial Revolution.\n\t\t\n',
#   '\n\t\t\t8.422\t\t',
#   '\n\t\t\t8.66\t\t',
#   '\n\t\t\t27313\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t4\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/wg9oOLcsKvDesSUdZQ4rxw__micro/img/LUkXZhd1TO80eCiXMD3-KfnzA6k=/fit-in/64x64/filters:strip_icc()/pic3536616.jpg',
#   '\n\n\nTerraforming Mars\n(2016)\n\n\n\t\t\tCompete with rival CEOs to make Mars habitable and build your corporate empire.\n\t\t\n',
#   '\n\t\t\t8.269\t\t',
#   '\n\t\t\t8.41\t\t',
#   '\n\t\t\t77092\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t5\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/_HhIdavYW-hid20Iq3hhmg__micro/img/OdKjWiFsNvQAfJfXXSITttiozWE=/fit-in/64x64/filters:strip_icc()/pic5055631.jpg',
#   '\n\n\nGloomhaven: Jaws of the Lion\n(2020)\n\n\n\t\t\tVanquish monsters with strategic cardplay in a 25-scenario Gloomhaven campaign.\n\t\t\n',
#   '\n\t\t\t8.267\t\t',
#   '\n\t\t\t8.65\t\t',
#   '\n\t\t\t18306\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t6\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/_Ppn5lssO5OaildSE-FgFA__micro/img/2gymaKs35_2yj7eyyA6cYyVmd9c=/fit-in/64x64/filters:strip_icc()/pic3727516.jpg',
#   '\n\n\nTwilight Imperium: Fourth Edition\n(2017)\n\n\n\t\t\tBuild an intergalactic empire through trade, research, conquest and grand politics.\n\t\t\n',
#   '\n\t\t\t8.256\t\t',
#   '\n\t\t\t8.66\t\t',
#   '\n\t\t\t16792\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t7\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/hGWFm3hbMlCDsfCsauOQ4g__micro/img/odWj2bEnZi9dEcQQrOtYj1e0QLE=/fit-in/64x64/filters:strip_icc()/pic5375625.png',
#   '\n\n\nGaia Project\n(2017)\n\n\n\t\t\tExpand, research, upgrade, and settle the galaxy with one of 14 alien species.\n\t\t\n',
#   '\n\t\t\t8.173\t\t',
#   '\n\t\t\t8.47\t\t',
#   '\n\t\t\t20213\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t8\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/7SrPNGBKg9IIsP4UQpOi8g__micro/img/nEvTiCkWpT-ymH4bstc9c335TtQ=/fit-in/64x64/filters:strip_icc()/pic4325841.jpg',
#   '\n\n\nStar Wars: Rebellion\n(2016)\n\n\n\t\t\tStrike from your hidden base as the Rebels—or find and destroy it as the Empire.\n\t\t\n',
#   '\n\t\t\t8.169\t\t',
#   '\n\t\t\t8.42\t\t',
#   '\n\t\t\t26313\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t9\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/a13ieMPP2s0KEaKNYmtH5w__micro/img/HQaHfx5cy6wJtZBMZCbVeNbfdy8=/fit-in/64x64/filters:strip_icc()/pic3615739.png',
#   '\n\n\nSpirit Island\n(2017)\n\n\n\t\t\tIsland Spirits join forces using elemental powers to defend their home from invaders.\n\t\t\n',
#   '\n\t\t\t8.142\t\t',
#   '\n\t\t\t8.36\t\t',
#   '\n\t\t\t34294\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t10\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/ImPgGag98W6gpV1KV812aA__micro/img/NT-Av_3kdYUcwuti5ocmIQXow3g=/fit-in/64x64/filters:strip_icc()/pic1215633.jpg',
#   '\n\n\nWar of the Ring: Second Edition\n(2011)\n\n\n\t\t\tThe Fellowship and the Free Peoples clash with Sauron over the fate of Middle-Earth.\n\t\t\n',
#   '\n\t\t\t8.141\t\t',
#   '\n\t\t\t8.52\t\t',
#   '\n\t\t\t16056\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t11\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/fVwPntkJKgaEo0rIC0RwpA__micro/img/77dZJpqtydc8TTecl0ReGF7iAVw=/fit-in/64x64/filters:strip_icc()/pic2663291.jpg',
#   '\n\n\nThrough the Ages: A New Story of Civilization\n(2015)\n\n\n\t\t\tRewrite history as you build up your civilization in this epic card drafting game!\n\t\t\n',
#   '\n\t\t\t8.141\t\t',
#   '\n\t\t\t8.37\t\t',
#   '\n\t\t\t26312\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t12\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/u1l0gH7sb_vnvDvoO_QHqA__micro/img/xeShpQfbj4L1id-ItJbfIYVzgyA=/fit-in/64x64/filters:strip_icc()/pic4887376.jpg',
#   '\n\n\nGreat Western Trail\n(2016)\n\n\n\t\t\tUse strategic outposts and navigate danger as you herd your cattle to Kansas City.\n\t\t\n',
#   '\n\t\t\t8.120\t\t',
#   '\n\t\t\t8.29\t\t',
#   '\n\t\t\t33958\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t13\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/pNCiUUphnoeWOYfsWq0kng__micro/img/ZlfJiIATIt5MY7xWSMzFmdygaa0=/fit-in/64x64/filters:strip_icc()/pic3530661.jpg',
#   '\n\n\nTwilight Struggle\n(2005)\n\n\n\t\t\tRelive the Cold War and rewrite history in an epic clash between the USA and USSR.\n\t\t\n',
#   '\n\t\t\t8.110\t\t',
#   '\n\t\t\t8.28\t\t',
#   '\n\t\t\t43671\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t14\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/7k_nOxpO9OGIjhLq2BUZdA__micro/img/ETplc22GdhlN5u0mppcDxSP8LVk=/fit-in/64x64/filters:strip_icc()/pic3163924.jpg',
#   '\n\n\nScythe\n(2016)\n\n\n\t\t\tFive factions vie for dominance in a war-torn, mech-filled, dieselpunk 1920s Europe.\n\t\t\n',
#   '\n\t\t\t8.059\t\t',
#   '\n\t\t\t8.21\t\t',
#   '\n\t\t\t66884\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t15\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/PhjygpWSo-0labGrPBMyyg__micro/img/mfU7-dEFnVyXJrF-BWAO0buexao=/fit-in/64x64/filters:strip_icc()/pic5666597.jpg',
#   '\n\n\nDune: Imperium\n(2020)\n\n\n\t\t\tInfluence, intrigue, and combat in the universe of Dune.\n\t\t\n',
#   '\n\t\t\t8.018\t\t',
#   '\n\t\t\t8.33\t\t',
#   '\n\t\t\t18424\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t16\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/5CFwjd8zTcGYVUnkXh04hw__micro/img/N1VrEUaW6bmwnqbZfi2nRScwGxM=/fit-in/64x64/filters:strip_icc()/pic1176894.jpg',
#   '\n\n\nThe Castles of Burgundy\n(2011)\n\n\n\t\t\tPlan, trade, and build your Burgundian estate to prosperity and prominence.\n\t\t\n',
#   '\n\t\t\t8.006\t\t',
#   '\n\t\t\t8.13\t\t',
#   '\n\t\t\t51864\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t17\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/tAqLpWxQ0Oo3GaPP3MER1g__micro/img/tivhH093LwCowK-_S7bVF_xha34=/fit-in/64x64/filters:strip_icc()/pic5073276.jpg',
#   '\n\n\nNemesis\n(2018)\n\n\n\t\t\tSurvive an alien-infested spaceship but beware of other players and their agendas.\n\t\t\n',
#   '\n\t\t\t7.987\t\t',
#   '\n\t\t\t8.38\t\t',
#   '\n\t\t\t19175\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t18\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/WzNs1mA_o22ZWTR8fkLP2g__micro/img/xh3isprMbt_FCg9vs3w_ifv-JXY=/fit-in/64x64/filters:strip_icc()/pic3376065.jpg',
#   '\n\n\n7 Wonders Duel\n(2015)\n\n\n\t\t\tScience? Military? What will you draft to win this head-to-head version of 7 Wonders?\n\t\t\n',
#   '\n\t\t\t7.983\t\t',
#   '\n\t\t\t8.11\t\t',
#   '\n\t\t\t72475\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t19\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/CzwSm8i7tkLz6cBnrILZBg__micro/img/FQyxREkHBn7yTbGmBg7c44eLgaM=/fit-in/64x64/filters:strip_icc()/pic3453267.jpg',
#   '\n\n\nConcordia\n(2013)\n\n\n\t\t\tLead your Roman dynasty and build the greatest trading empire in the Mediterranean.\n\t\t\n',
#   '\n\t\t\t7.968\t\t',
#   '\n\t\t\t8.12\t\t',
#   '\n\t\t\t32560\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t20\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/tHVtPzu82mBpeQbbZkV6EA__micro/img/jM8d5Q5btvJmcWQN_px-A-nlueI=/fit-in/64x64/filters:strip_icc()/pic3469216.jpg',
#   '\n\n\nBrass: Lancashire\n(2007)\n\n\n\t\t\tTest your economic mettle as you build and network in the Industrial Revolution.\n\t\t\n',
#   '\n\t\t\t7.966\t\t',
#   '\n\t\t\t8.18\t\t',
#   '\n\t\t\t21314\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t21\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/bre12I1YiXkZr7elvriz4A__micro/img/SAwaBrDhHbGuq6dFY-ok95qFMcU=/fit-in/64x64/filters:strip_icc()/pic5375624.jpg',
#   '\n\n\nTerra Mystica\n(2012)\n\n\n\t\t\tPlay fantastical factions.  Expand your influence by terraforming and joining cults.\n\t\t\n',
#   '\n\t\t\t7.958\t\t',
#   '\n\t\t\t8.12\t\t',
#   '\n\t\t\t42539\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t22\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/s9oGMCo1fcfV4Dk3EnqLZw__micro/img/JCrcuFDrjVQ64uLbqpH-Pmg6XsU=/fit-in/64x64/filters:strip_icc()/pic3146943.png',
#   '\n\n\nA Feast for Odin\n(2016)\n\n\n\t\t\tPuzzle together the life of a Viking village as you hunt, farm, craft, and explore.\n\t\t\n',
#   '\n\t\t\t7.953\t\t',
#   '\n\t\t\t8.20\t\t',
#   '\n\t\t\t21370\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t23\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/yLZJCVLlIx4c7eJEWUNJ7w__micro/img/5ZaRePVhfelfofF7T_OC1e0gUCw=/fit-in/64x64/filters:strip_icc()/pic4458123.jpg',
#   '\n\n\nWingspan\n(2019)\n\n\n\t\t\tAttract a beautiful and diverse collection of birds to your wildlife reserve.\n\t\t\n',
#   '\n\t\t\t7.943\t\t',
#   '\n\t\t\t8.10\t\t',
#   '\n\t\t\t60195\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t24\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/RdCWCXPnBGSxoOhk5Hkq_g__micro/img/TVx3_34ywzwURntW1WMKBx6ZeCg=/fit-in/64x64/filters:strip_icc()/pic6530423.jpg',
#   '\n\n\nArkham Horror: The Card Game\n(2016)\n\n\n\t\t\tInvestigate the horrors of Arkham while courting cosmic doom.\n\t\t\n',
#   '\n\t\t\t7.926\t\t',
#   '\n\t\t\t8.16\t\t',
#   '\n\t\t\t34490\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t25\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/l_PRU2lVlX9seScRFcvFlA__micro/img/3EqHlTkNSnZNFHVaAeFSpzfzuIQ=/fit-in/64x64/filters:strip_icc()/pic6500949.jpg',
#   "\n\n\nViticulture Essential Edition\n(2015)\n\n\n\t\t\tCreate the most prosperous winery in Italy from the Tuscan vineyard you've inherited.\n\t\t\n",
#   '\n\t\t\t7.891\t\t',
#   '\n\t\t\t8.05\t\t',
#   '\n\t\t\t36505\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t26\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/JUAUWaVUzeBgzirhZNmHHw__micro/img/tdHLiMYfi-KTy89sGBGZVeE9ts0=/fit-in/64x64/filters:strip_icc()/pic4254509.jpg',
#   '\n\n\nRoot\n(2018)\n\n\n\t\t\tDecide the fate of the forest as woodland factions fight for contrasting goals.\n\t\t\n',
#   '\n\t\t\t7.889\t\t',
#   '\n\t\t\t8.10\t\t',
#   '\n\t\t\t33655\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t27\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/nagl1li6kYt9elV9jbfVQw__micro/img/hUKCvnqgFvTl0aOMd8FLkgCObT0=/fit-in/64x64/filters:strip_icc()/pic6228507.jpg',
#   '\n\n\nOrléans\n(2014)\n\n\n\t\t\tCraftsmen, scholars & monks can help you reign supreme—but who will turn up to help?\n\t\t\n',
#   '\n\t\t\t7.884\t\t',
#   '\n\t\t\t8.07\t\t',
#   '\n\t\t\t25390\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t28\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/fjE7V5LNq31yVEW_yuqI-Q__micro/img/TAgkPCJdNAIHZfn1BE1DXadBL9g=/fit-in/64x64/filters:strip_icc()/pic3918905.png',
#   '\n\n\nEverdell\n(2018)\n\n\n\t\t\tUse resources to build a village of critters and constructions in this woodland game.\n\t\t\n',
#   '\n\t\t\t7.882\t\t',
#   '\n\t\t\t8.09\t\t',
#   '\n\t\t\t31949\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t29\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/hc2NDafu5c24iLJh_IZmyg__micro/img/v2WzacDprYF837E6h9O2WuFFmpw=/fit-in/64x64/filters:strip_icc()/pic4885780.png',
#   '\n\n\nClank!: Legacy – Acquisitions Incorporated\n(2019)\n\n\n\t\t\t"Go forth, be bold, and ACQUIRE!" in this campaign version of "Clank!"\n\t\t\n',
#   '\n\t\t\t7.876\t\t',
#   '\n\t\t\t8.67\t\t',
#   '\n\t\t\t5536\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t30\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/DUO2hz9AlLOH8p9ED-lCWg__micro/img/eXzdbUmCbIdMIVgiQ_QwS3YNOS4=/fit-in/64x64/filters:strip_icc()/pic1083380.jpg',
#   '\n\n\nMage Knight Board Game\n(2011)\n\n\n\t\t\tBuild your hero’s spells, abilities, and artifacts as you explore & conquer cities.\n\t\t\n',
#   '\n\t\t\t7.875\t\t',
#   '\n\t\t\t8.10\t\t',
#   '\n\t\t\t29861\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t31\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/6GqH14TJJhza86BX5HCLEQ__micro/img/2FKVaukjh9a-Kg9LWQuMSvLS34s=/fit-in/64x64/filters:strip_icc()/pic5674958.jpg',
#   '\n\n\nLost Ruins of Arnak\n(2020)\n\n\n\t\t\tExplore an island to find resources and discover the lost ruins of Arnak.\n\t\t\n',
#   '\n\t\t\t7.862\t\t',
#   '\n\t\t\t8.12\t\t',
#   '\n\t\t\t20814\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t32\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/Oh3kHw6lweg6ru71Q16h2Q__micro/img/vhB59zFDq3Kul0xbr3api2selZs=/fit-in/64x64/filters:strip_icc()/pic5235277.jpg',
#   '\n\n\nEclipse: Second Dawn for the Galaxy\n(2020)\n\n\n\t\t\tBuild an interstellar civilization by exploration, research, conquest, and diplomacy.\n\t\t\n',
#   '\n\t\t\t7.861\t\t',
#   '\n\t\t\t8.65\t\t',
#   '\n\t\t\t6317\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t33\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/Wtxml94LAXsIWQCxGPS63Q__micro/img/4Oucoa190njfSaNHr8YRIl6UnTU=/fit-in/64x64/filters:strip_icc()/pic2649434.png',
#   '\n\n\nFood Chain Magnate\n(2015)\n\n\n\t\t\tStrategically hire and manage your workforce to outcompete rival fast food chains.\n\t\t\n',
#   '\n\t\t\t7.834\t\t',
#   '\n\t\t\t8.11\t\t',
#   '\n\t\t\t15970\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t34\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/QFiIRd2kimaMqTyWsX0aUg__micro/img/ggNIAA1GEadqvcY7Mvwb9_VEybU=/fit-in/64x64/filters:strip_icc()/pic158548.jpg',
#   '\n\n\nPuerto Rico\n(2002)\n\n\n\t\t\tShip goods, construct buildings, and choose roles that benefit you more than others.\n\t\t\n',
#   '\n\t\t\t7.831\t\t',
#   '\n\t\t\t7.96\t\t',
#   '\n\t\t\t66141\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t35\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/rz22tqa5PCYvK9oDjIbvxg__micro/img/sog7ni3vUAAfvd66e6XW4iOca4I=/fit-in/64x64/filters:strip_icc()/pic1790789.jpg',
#   '\n\n\nCaverna: The Cave Farmers\n(2013)\n\n\n\t\t\tFrom a simple cave, expand your dwarven home through mining, agriculture, and more.\n\t\t\n',
#   '\n\t\t\t7.820\t\t',
#   '\n\t\t\t8.00\t\t',
#   '\n\t\t\t30315\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t36\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/HkZSJfQnZ3EpS214xtuplg__micro/img/7xdR1_OUo1ReAvYzhi7jBhFMHu0=/fit-in/64x64/filters:strip_icc()/pic2439223.jpg',
#   '\n\n\nBlood Rage\n(2015)\n\n\n\t\t\tRagnarök has come! Secure your place in Valhalla in epic Viking battles.\n\t\t\n',
#   '\n\t\t\t7.812\t\t',
#   '\n\t\t\t7.99\t\t',
#   '\n\t\t\t38798\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t37\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/kRvUgYiaOq07kC67ZK5UoQ__micro/img/4DLQr45lpVBfCkiy-kVwhl4z4vQ=/fit-in/64x64/filters:strip_icc()/pic4900321.jpg',
#   '\n\n\nMarvel Champions: The Card Game\n(2019)\n\n\n\t\t\tBattle Marvel villains with unique teams of iconic heroes in this LCG.\n\t\t\n',
#   '\n\t\t\t7.809\t\t',
#   '\n\t\t\t8.20\t\t',
#   '\n\t\t\t15336\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t38\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/wKwRk0wYBcrtLAfgn4PCdg__micro/img/Q6VXZKoVSlMjTU7Vp8tn1tkcVzw=/fit-in/64x64/filters:strip_icc()/pic6624445.png',
#   '\n\n\nToo Many Bones\n(2017)\n\n\n\t\t\tToss gobs of unique dice in an epic adventure en route to a final boss showdown.\n\t\t\n',
#   '\n\t\t\t7.806\t\t',
#   '\n\t\t\t8.42\t\t',
#   '\n\t\t\t8282\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t39\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/dDDo2Hexl80ucK1IlqTk-g__micro/img/SZgGqufNqaW8BCFT29wkYPaRXOE=/fit-in/64x64/filters:strip_icc()/pic831744.jpg',
#   "\n\n\nAgricola\n(2007)\n\n\n\t\t\tBuild your farmstead by sowing fields and raising livestock. But don't forget to eat!\n\t\t\n",
#   '\n\t\t\t7.802\t\t',
#   '\n\t\t\t7.92\t\t',
#   '\n\t\t\t66946\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t40\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/jEPmWvvYpqkWrKOzqIHFsg__micro/img/Uwm0ZfmY4ZNWWxlackDXrsmS-Io=/fit-in/64x64/filters:strip_icc()/pic4336469.png',
#   '\n\n\nBarrage\n(2019)\n\n\n\t\t\tNations vie for hydroelectric dominance in a dystopia where water is power.\n\t\t\n',
#   '\n\t\t\t7.797\t\t',
#   '\n\t\t\t8.23\t\t',
#   '\n\t\t\t10258\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t41\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/rMNa0k05zMdKgSEp26Q3Tw__micro/img/rDI-yCgwVbB_szRjUWOY8IKIdUk=/fit-in/64x64/filters:strip_icc()/pic4917407.jpg',
#   '\n\n\nMaracaibo\n(2019)\n\n\n\t\t\tSeafarers journey to obtain wealth and fame in the 17th century Caribbean.\n\t\t\n',
#   '\n\t\t\t7.787\t\t',
#   '\n\t\t\t8.18\t\t',
#   '\n\t\t\t11424\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t42\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/PwOwTVHovJAUQgghnGqCOg__micro/img/9ftDcGDumAWKm_3hmu6JUwjb1aU=/fit-in/64x64/filters:strip_icc()/pic4837710.png',
#   '\n\n\nUnderwater Cities\n(2018)\n\n\n\t\t\tDevelop future cities on the seafloor through politics, production, and science.\n\t\t\n',
#   '\n\t\t\t7.779\t\t',
#   '\n\t\t\t8.10\t\t',
#   '\n\t\t\t13544\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t43\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/Qtkb-UTvHa0-kxt_MK1nKw__micro/img/eYV_Y45Hk66WceHroLlRqnHEHmg=/fit-in/64x64/filters:strip_icc()/pic3763549.jpg',
#   '\n\n\nPandemic Legacy: Season 2\n(2017)\n\n\n\t\t\tThe world is a mystery after a devastating pandemic—where will your team go?\n\t\t\n',
#   '\n\t\t\t7.778\t\t',
#   '\n\t\t\t8.10\t\t',
#   '\n\t\t\t14106\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t44\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/LIooA9bTdjnE9qmhjL-UFw__micro/img/rsUu4YzIErI1oi6TRRA-cKiS-I0=/fit-in/64x64/filters:strip_icc()/pic3118622.jpg',
#   '\n\n\nMansions of Madness: Second Edition\n(2016)\n\n\n\t\t\tUnravel mysteries in Arkham with your investigative team in this app-guided game.\n\t\t\n',
#   '\n\t\t\t7.776\t\t',
#   '\n\t\t\t8.01\t\t',
#   '\n\t\t\t29513\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t45\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/oSM_AuKYfGIwOtKbVEsoVg__micro/img/SKUliR88eoltB2ytmwz3BffW7aA=/fit-in/64x64/filters:strip_icc()/pic4503733.png',
#   '\n\n\nPax Pamir: Second Edition\n(2019)\n\n\n\t\t\tSwing the tides of "The Great Game" as countries vie for control of Afghanistan.\n\t\t\n',
#   '\n\t\t\t7.771\t\t',
#   '\n\t\t\t8.35\t\t',
#   '\n\t\t\t7638\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t46\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/98LnQShydr11OBKS46xY-Q__micro/img/bIVTqYzQ5wDuCSmcQvpNokXZOUo=/fit-in/64x64/filters:strip_icc()/pic5687013.jpg',
#   '\n\n\nThe Crew: The Quest for Planet Nine\n(2019)\n\n\n\t\t\tGo on a planet-discovering space mission in this cooperative trick-taking game.\n\t\t\n',
#   '\n\t\t\t7.767\t\t',
#   '\n\t\t\t7.95\t\t',
#   '\n\t\t\t27466\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t47\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/31quLNzteInnevVRAABoow__micro/img/CMEokoPk9cBV5A82_eBwjDJPMfE=/fit-in/64x64/filters:strip_icc()/pic3499707.jpg',
#   '\n\n\nAnachrony\n(2017)\n\n\n\t\t\tUse Exosuits & time travel to ensure your vision for the future after the cataclysm.\n\t\t\n',
#   '\n\t\t\t7.754\t\t',
#   '\n\t\t\t8.11\t\t',
#   '\n\t\t\t13802\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t48\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/kXf7mDyDYuHg6oe8yTUIEA__micro/img/3EqJtoxAlTb2pJWxmA7TUu4HWNI=/fit-in/64x64/filters:strip_icc()/pic4604439.jpg',
#   "\n\n\nTzolk'in: The Mayan Calendar\n(2012)\n\n\n\t\t\tLead your people, build monuments and make offerings to earn the favour of the gods.\n\t\t\n",
#   '\n\t\t\t7.737\t\t',
#   '\n\t\t\t7.89\t\t',
#   '\n\t\t\t33966\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t49\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/yd6LuatytHRhcFCxCf-EEg__micro/img/ZUrGKfXAZS4AztFRXq2W9oD6TG4=/fit-in/64x64/filters:strip_icc()/pic4459753.jpg',
#   '\n\n\nPower Grid\n(2004)\n\n\n\t\t\tBid, network, and manage resources in a race to supply the most cities with power.\n\t\t\n',
#   '\n\t\t\t7.734\t\t',
#   '\n\t\t\t7.84\t\t',
#   '\n\t\t\t59405\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t50\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/LenzJBOHboAGU0cUIqAZPQ__micro/img/6YI32BDhyuO9JZrofc1CPbuFlVY=/fit-in/64x64/filters:strip_icc()/pic2931007.jpg',
#   '\n\n\nKingdom Death: Monster\n(2015)\n\n\n\t\t\tTry to survive in a nightmarish world that lies under eternal darkness.\n\t\t\n',
#   '\n\t\t\t7.722\t\t',
#   '\n\t\t\t8.58\t\t',
#   '\n\t\t\t8292\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t51\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/SPuwc6RJ6y4PnTH36Pegsg__micro/img/wWI0kOjt4L4TOOV_Dn2BLthq5QQ=/fit-in/64x64/filters:strip_icc()/pic3511783.png',
#   '\n\n\nClans of Caledonia\n(2017)\n\n\n\t\t\tLead your unique Scottish clan to economic might via production, trade, and export.\n\t\t\n',
#   '\n\t\t\t7.721\t\t',
#   '\n\t\t\t7.98\t\t',
#   '\n\t\t\t17223\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t52\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/Nm0Iw8NoiM9V8IsifimGBw__micro/img/HQNReYu8QkZqD4dbZeWg3cQrkv0=/fit-in/64x64/filters:strip_icc()/pic4357658.jpg',
#   '\n\n\nOn Mars\n(2020)\n\n\n\t\t\tBe a part of the first Martian colony, striving to be the best contributor.\n\t\t\n',
#   '\n\t\t\t7.715\t\t',
#   '\n\t\t\t8.25\t\t',
#   '\n\t\t\t8367\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t53\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/pIQ_MXvaoARRp1loCHJuHg__micro/img/i2soAnlvaDCzWksrpO2By4-GgGA=/fit-in/64x64/filters:strip_icc()/pic2247647.jpg',
#   '\n\n\nStar Wars: Imperial Assault\n(2014)\n\n\n\t\t\tPlay as Rebel or Imperial forces to fulfill mission objectives.\n\t\t\n',
#   '\n\t\t\t7.715\t\t',
#   '\n\t\t\t7.99\t\t',
#   '\n\t\t\t22149\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t54\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/n4J5LebMj0DQD016qW7ABw__micro/img/n4vvAq2JZvjf0yS_Mugr79dqM90=/fit-in/64x64/filters:strip_icc()/pic3184103.jpg',
#   '\n\n\nMechs vs. Minions\n(2016)\n\n\n\t\t\tCooperatively program and pilot your mechs to defeat an army of marauding minions.\n\t\t\n',
#   '\n\t\t\t7.714\t\t',
#   '\n\t\t\t8.02\t\t',
#   '\n\t\t\t15438\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t55\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/y7Rqd3S6J7vyVhicR1bqTQ__micro/img/c1qPt4uwG4qhjxmrgtIuKulwQkI=/fit-in/64x64/filters:strip_icc()/pic6091101.jpg',
#   '\n\n\nLe Havre\n(2008)\n\n\n\t\t\tEstablish a supply chain by collecting resources, building industries, and shipping.\n\t\t\n',
#   '\n\t\t\t7.712\t\t',
#   '\n\t\t\t7.87\t\t',
#   '\n\t\t\t28498\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t56\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/OYne8uBCHv5oEgRfpOrV0A__micro/img/8IGVzvGADTyV8kjaMNw-VCBL4TY=/fit-in/64x64/filters:strip_icc()/pic2648303.jpg',
#   '\n\n\nThe 7th Continent\n(2017)\n\n\n\t\t\tJourney through a vibrant but deadly land to uncover the key to lifting your curse.\n\t\t\n',
#   '\n\t\t\t7.702\t\t',
#   '\n\t\t\t8.01\t\t',
#   '\n\t\t\t19332\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t57\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/SoU8p28Sk1s8MSvoM4N8pQ__micro/img/LSAi1pmhbTbWwtBrziutDOXzfdY=/fit-in/64x64/filters:strip_icc()/pic6293412.jpg',
#   '\n\n\nArk Nova\n(2021)\n\n\n\t\t\tDesign a modern zoo to run a successful park and to support conservation projects.\n\t\t\n',
#   '\n\t\t\t7.694\t\t',
#   '\n\t\t\t8.68\t\t',
#   '\n\t\t\t4279\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t58\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/pH5LgRL4mNRon-2NsSDb1Q__micro/img/pAWwGfiqFpn-kkzUKexMTZOvoA4=/fit-in/64x64/filters:strip_icc()/pic6137509.png',
#   '\n\n\nThe Quacks of Quedlinburg\n(2018)\n\n\n\t\t\tPull ingredients from your stock to make your pot bubble, but hopefully not explode!\n\t\t\n',
#   '\n\t\t\t7.690\t\t',
#   '\n\t\t\t7.85\t\t',
#   '\n\t\t\t32122\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t59\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/ie1GSt1XV04sXQXt-3O1UQ__micro/img/Zxap2me5W8VgLK_VNU_lY5vLnbA=/fit-in/64x64/filters:strip_icc()/pic2503200.png',
#   '\n\n\nThe Gallerist\n(2015)\n\n\n\t\t\tAmass a fortune, and stake your reputation by operating a lucrative art gallery.\n\t\t\n',
#   '\n\t\t\t7.686\t\t',
#   '\n\t\t\t8.05\t\t',
#   '\n\t\t\t11505\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t60\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/7ejbxsn-UtLl3ehamuAEdw__micro/img/5UygdMxz3N_dTCkGlwVlgJXK_vg=/fit-in/64x64/filters:strip_icc()/pic79413.jpg',
#   '\n\n\nCrokinole\n(1876)\n\n\n\t\t\tFlick discs and make trick shots in this traditional Canadian dexterity game!\n\t\t\n',
#   '\n\t\t\t7.685\t\t',
#   '\n\t\t\t7.96\t\t',
#   '\n\t\t\t13895\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t61\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/OrHS8_a1CqSGiXeTfCk0Wg__micro/img/rpfZR0COMOP41SI2EZPrSrX_LL8=/fit-in/64x64/filters:strip_icc()/pic3209553.jpg',
#   '\n\n\nLisboa\n(2017)\n\n\n\t\t\tCompete to reconstruct the city of Lisboa after the great earthquake of 1755.\n\t\t\n',
#   '\n\t\t\t7.683\t\t',
#   '\n\t\t\t8.20\t\t',
#   '\n\t\t\t8199\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t62\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/tz19PfklMdAdjxV9WArraA__micro/img/N7xRslgynWzB3aObMBI9F1yKfQ8=/fit-in/64x64/filters:strip_icc()/pic3718275.jpg',
#   '\n\n\nAzul\n(2017)\n\n\n\t\t\tArtfully embellish the walls of your palace by drafting the most beautiful tiles.\n\t\t\n',
#   '\n\t\t\t7.679\t\t',
#   '\n\t\t\t7.79\t\t',
#   '\n\t\t\t66009\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t63\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/cnFppsVNOSTJ-W3APQFuTg__micro/img/dfQTNAju5CUxn6JQl-Pxubac99o=/fit-in/64x64/filters:strip_icc()/pic1974056.jpg',
#   '\n\n\nEclipse\n(2011)\n\n\n\t\t\tBuild an interstellar civilization by exploration, research, conquest, and diplomacy.\n\t\t\n',
#   '\n\t\t\t7.676\t\t',
#   '\n\t\t\t7.87\t\t',
#   '\n\t\t\t27004\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t64\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/3piN3YX4WmBRuIvbEG2Ygg__micro/img/xy_566fY112BYtYJjT29cfAcHsk=/fit-in/64x64/filters:strip_icc()/pic236169.jpg',
#   '\n\n\nThrough the Ages: A Story of Civilization\n(2006)\n\n\n\t\t\tLead your civilization through strategic drafting of leaders, technologies, and more.\n\t\t\n',
#   '\n\t\t\t7.668\t\t',
#   '\n\t\t\t7.90\t\t',
#   '\n\t\t\t18482\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t65\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/4nhokcLdYoo6ulbZ1rmGgA__micro/img/WMzScSxJICvIyErl47KBVoskhnQ=/fit-in/64x64/filters:strip_icc()/pic4462987.png',
#   '\n\n\nPaladins of the West Kingdom\n(2019)\n\n\n\t\t\tInvaders are coming from everywhere.  Keep the faith and defend your homeland.\n\t\t\n',
#   '\n\t\t\t7.667\t\t',
#   '\n\t\t\t8.03\t\t',
#   '\n\t\t\t11999\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t66\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/d50LceHj6LIafa4S_qIsCg__micro/img/0El7f9TAr9UfvKlcsXYrBe8jEOc=/fit-in/64x64/filters:strip_icc()/pic3189350.jpg',
#   "\n\n\nAeon's End\n(2016)\n\n\n\t\t\tMages defend humanity’s last city, harnessing alien powers to destroy monstrosities.\n\t\t\n",
#   '\n\t\t\t7.666\t\t',
#   '\n\t\t\t8.00\t\t',
#   '\n\t\t\t14661\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t67\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/2ewHIIG_TRq8bYlqk0jIMw__micro/img/U5irACQ5P-7X9XyeDWj71ai-Ruw=/fit-in/64x64/filters:strip_icc()/pic3738560.jpg',
#   '\n\n\nAndroid: Netrunner\n(2012)\n\n\n\t\t\tMegacorporation versus Netrunner in this futuristic cyberpunk game of cat and mouse.\n\t\t\n',
#   '\n\t\t\t7.665\t\t',
#   '\n\t\t\t7.88\t\t',
#   '\n\t\t\t27984\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t68\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/y0x1zbkpUXjddzWWnhekYw__micro/img/oUW7QBHTiMOcpt5FgNXd_Uy2LfM=/fit-in/64x64/filters:strip_icc()/pic5581457.jpg',
#   '\n\n\nPandemic Legacy: Season 0\n(2020)\n\n\n\t\t\tWork together during the Cold War to prevent a Soviet bio-threat.\n\t\t\n',
#   '\n\t\t\t7.652\t\t',
#   '\n\t\t\t8.61\t\t',
#   '\n\t\t\t4163\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t69\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/-DOqixs8uwKUvvWPKI4f9w__micro/img/Fz_qRw_ZHI9TfZXY0b4YZ6zfT7o=/fit-in/64x64/filters:strip_icc()/pic5261714.jpg',
#   "\n\n\nRace for the Galaxy\n(2007)\n\n\n\t\t\tWorlds await! Colonize, develop and conquer taking advantage of others' choices.\n\t\t\n",
#   '\n\t\t\t7.650\t\t',
#   '\n\t\t\t7.76\t\t',
#   '\n\t\t\t49650\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t70\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/DPjV1iI0ygo5Bl3XLNRiIg__micro/img/5hO7ln_bquTyy4Q__ksB4NT1gMs=/fit-in/64x64/filters:strip_icc()/pic4449526.jpg',
#   "\n\n\nClank!: A Deck-Building Adventure\n(2016)\n\n\n\t\t\tClaim your treasures but don't attract the dragon in this deck-building dungeon race.\n\t\t\n",
#   '\n\t\t\t7.647\t\t',
#   '\n\t\t\t7.81\t\t',
#   '\n\t\t\t33277\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t71\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/0w8go6cfvlpgJKydHUkDtA__micro/img/9JEU9pIfwl2wUIE3fmCmjjH_iiM=/fit-in/64x64/filters:strip_icc()/pic2225968.png',
#   '\n\n\nFields of Arle\n(2014)\n\n\n\t\t\tConstruct dikes, drain bogs, harvest flax and tend to newborn animals in East Frisia.\n\t\t\n',
#   '\n\t\t\t7.646\t\t',
#   '\n\t\t\t8.07\t\t',
#   '\n\t\t\t9301\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t72\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/FbFnaTx3aT5dM18K_bR_Pg__micro/img/brcsM5-72GgeBDQg3CSI6VB1Dqo=/fit-in/64x64/filters:strip_icc()/pic3165731.jpg',
#   '\n\n\nRobinson Crusoe: Adventures on the Cursed Island\n(2012)\n\n\n\t\t\tWork together — with friends or with Friday — to survive on a deserted island.\n\t\t\n',
#   '\n\t\t\t7.640\t\t',
#   '\n\t\t\t7.81\t\t',
#   '\n\t\t\t37941\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t73\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/wW5xjgBJcFyLaEWZwrYuKA__micro/img/kXVTBtcGC-5L706WFNJLAuZTovQ=/fit-in/64x64/filters:strip_icc()/pic4583626.jpg',
#   '\n\n\nTeotihuacan: City of Gods\n(2018)\n\n\n\t\t\tUse your worker dice to raise the legendary and breathtaking Pyramid of the Sun.\n\t\t\n',
#   '\n\t\t\t7.637\t\t',
#   '\n\t\t\t7.92\t\t',
#   '\n\t\t\t15795\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t74\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/dmo-WD6HZHVUPrbVHunaTw__micro/img/fxKL3MvU00YeEkfeLNdQGUl5rxA=/fit-in/64x64/filters:strip_icc()/pic2055255.jpg',
#   '\n\n\nFive Tribes\n(2014)\n\n\n\t\t\tMove assassins, elders & builders through Naqala to claim oases & control djinns.\n\t\t\n',
#   '\n\t\t\t7.635\t\t',
#   '\n\t\t\t7.78\t\t',
#   '\n\t\t\t35573\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t75\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/n1G7_aWToLAAB7Mqt8iwyA__micro/img/c8Ld-3E8S0devFlugLvyiAEESbY=/fit-in/64x64/filters:strip_icc()/pic2461346.png',
#   '\n\n\nThe Voyages of Marco Polo\n(2015)\n\n\n\t\t\tUsing unique abilities, fulfill contracts and reach your goals along the Silk Road.\n\t\t\n',
#   '\n\t\t\t7.634\t\t',
#   '\n\t\t\t7.83\t\t',
#   '\n\t\t\t22216\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t76\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/RvFVTEpnbb4NM7k0IF8V7A__micro/img/9glsOs7zoTbkVpfDt5SHWJm-kRA=/fit-in/64x64/filters:strip_icc()/pic860217.jpg',
#   '\n\n\n7 Wonders\n(2010)\n\n\n\t\t\tDraft cards to develop your ancient civilization and build its Wonder of the World.\n\t\t\n',
#   '\n\t\t\t7.625\t\t',
#   '\n\t\t\t7.73\t\t',
#   '\n\t\t\t91778\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t77\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/Vf_0TrTfz9yll7rVBvYGsg__micro/img/-rkh8miCGz860ChoPFB0i_jjgog=/fit-in/64x64/filters:strip_icc()/pic3029377.jpg',
#   '\n\n\nAgricola (Revised Edition)\n(2016)\n\n\n\t\t\tHelp your farm to prosper in this updated, streamlined edition of the acclaimed game.\n\t\t\n',
#   '\n\t\t\t7.621\t\t',
#   '\n\t\t\t7.99\t\t',
#   '\n\t\t\t12360\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t78\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/-hk8f8iGk_DyWyMrfiPBkg__micro/img/tWSg9ErrwvVcwaE1Kze1IsxwpGg=/fit-in/64x64/filters:strip_icc()/pic1116080.jpg',
#   '\n\n\nLords of Waterdeep\n(2012)\n\n\n\t\t\tDeploy agents and hire adventurers to expand your control over the city of Waterdeep.\n\t\t\n',
#   '\n\t\t\t7.616\t\t',
#   '\n\t\t\t7.75\t\t',
#   '\n\t\t\t49525\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t79\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/oeygRZntjNUJWvc8SxDfww__micro/img/gXi23Nbfem6XTfRlV2eHEHB_cHY=/fit-in/64x64/filters:strip_icc()/pic784193.jpg',
#   '\n\n\nDominant Species\n(2010)\n\n\n\t\t\tWith an ice age approaching, which animals will best propagate, migrate, and adapt?\n\t\t\n',
#   '\n\t\t\t7.612\t\t',
#   '\n\t\t\t7.83\t\t',
#   '\n\t\t\t19004\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t80\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/d4It-gdWY4GZVYSjbq20gQ__micro/img/zmZ-XLYa4qxusS-9osWBmPd9lQs=/fit-in/64x64/filters:strip_icc()/pic2728138.jpg',
#   '\n\n\nGrand Austria Hotel\n(2015)\n\n\n\t\t\tServe guests and prepare rooms to be the best hotelier in the Viennese modern age.\n\t\t\n',
#   '\n\t\t\t7.606\t\t',
#   '\n\t\t\t7.88\t\t',
#   '\n\t\t\t15203\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t81\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/OAX7HfOz-9N60StgADzd0g__micro/img/5OEOXKjvrEMh2aT5I-FrAn5-9jo=/fit-in/64x64/filters:strip_icc()/pic3781944.png',
#   '\n\n\nArchitects of the West Kingdom\n(2018)\n\n\n\t\t\tWill you be a virtuous or nefarious servant of the king? Build your way to glory.\n\t\t\n',
#   '\n\t\t\t7.583\t\t',
#   '\n\t\t\t7.80\t\t',
#   '\n\t\t\t21654\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t82\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/VuBqZ1sMaDAVVHF_OEJP4g__micro/img/p3GKOrR04nV1qkim9zq-rmFfYh8=/fit-in/64x64/filters:strip_icc()/pic5988903.jpg',
#   '\n\n\nThe Crew: Mission Deep Sea\n(2021)\n\n\n\t\t\tDive into the deep sea in this co-operative trick-taking game.\n\t\t\n',
#   '\n\t\t\t7.582\t\t',
#   '\n\t\t\t8.41\t\t',
#   '\n\t\t\t4502\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t83\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/aAwBzPzta4joKfFZt05hCw__micro/img/28sp86TqPbMqn9M_qHWfS9j44-w=/fit-in/64x64/filters:strip_icc()/pic4385726.jpg',
#   '\n\n\nTainted Grail: The Fall of Avalon\n(2019)\n\n\n\t\t\tExploration, battle and diplomacy in a dark Arthurian realm.\n\t\t\n',
#   '\n\t\t\t7.582\t\t',
#   '\n\t\t\t8.22\t\t',
#   '\n\t\t\t8568\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t84\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/HbfgxDJZQnNEZQKvpmJxQg__micro/img/L6e_jaWDU2M5XPhV0lMhPPo26EU=/fit-in/64x64/filters:strip_icc()/pic2278942.jpg',
#   '\n\n\nKeyflower\n(2012)\n\n\n\t\t\tCompete in a unique auction system to build the most prosperous village.\n\t\t\n',
#   '\n\t\t\t7.580\t\t',
#   '\n\t\t\t7.77\t\t',
#   '\n\t\t\t20446\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t85\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/GO282hlXR3RiknU5W4GZjg__micro/img/Ya0GwTP0sOChJ3b0E3Ufmua39gw=/fit-in/64x64/filters:strip_icc()/pic5373572.png',
#   '\n\n\nEl Grande\n(1995)\n\n\n\t\t\tUse your caballeros to control regions of medieval Spain, keeping clear of the King!\n\t\t\n',
#   '\n\t\t\t7.575\t\t',
#   '\n\t\t\t7.75\t\t',
#   '\n\t\t\t24895\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t86\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/yC7nOSc1x5PT-oNnh6TEcQ__micro/img/R7ZK4KtIIQNR2CJHZ6HtUxEY8ik=/fit-in/64x64/filters:strip_icc()/pic1638795.jpg',
#   '\n\n\nCaylus\n(2005)\n\n\n\t\t\tEntrepreneurs pay workers & bribe an official to build a Château & gain royal favor.\n\t\t\n',
#   '\n\t\t\t7.569\t\t',
#   '\n\t\t\t7.75\t\t',
#   '\n\t\t\t27711\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t87\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/5Q2w2rFJiFI_uV89KP6ECg__micro/img/KGgAsbHUPaEjsl-r05JCH2ixP1o=/fit-in/64x64/filters:strip_icc()/pic354500.jpg',
#   "\n\n\nBattlestar Galactica: The Board Game\n(2008)\n\n\n\t\t\tHow can the human race survive when you don't know who is actually human?\n\t\t\n",
#   '\n\t\t\t7.563\t\t',
#   '\n\t\t\t7.74\t\t',
#   '\n\t\t\t34276\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t88\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/MHeQQrbauUVsvh2QF6PMog__micro/img/qq2rc5GmKHOr8Dpn5Q8di_FD6Cg=/fit-in/64x64/filters:strip_icc()/pic4128153.jpg',
#   '\n\n\nTwilight Imperium: Third Edition\n(2005)\n\n\n\t\t\tEpic empire-building game of interstellar conflict, trade, and struggle for power.\n\t\t\n',
#   '\n\t\t\t7.553\t\t',
#   '\n\t\t\t7.82\t\t',
#   '\n\t\t\t18721\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t89\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/fBIe-aEPtJKC-ceNlspK6A__micro/img/6ZLZgf_o1omV4ijqi2OLJWK_GM0=/fit-in/64x64/filters:strip_icc()/pic750583.jpg',
#   '\n\n\nTroyes\n(2010)\n\n\n\t\t\tDefend the city and rise to power by influencing the merchants, knights and clergy.\n\t\t\n',
#   '\n\t\t\t7.551\t\t',
#   '\n\t\t\t7.75\t\t',
#   '\n\t\t\t20601\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t90\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/OGOmpi0GgwOwH2y28QgkuA__micro/img/VlsgqS2v915vSCwTPVWFVms0-TY=/fit-in/64x64/filters:strip_icc()/pic460011.jpg',
#   '\n\n\nDominion: Intrigue\n(2009)\n\n\n\t\t\tEnlist torturers, swindlers, and saboteurs to gain wealth and dominate the kingdom.\n\t\t\n',
#   '\n\t\t\t7.549\t\t',
#   '\n\t\t\t7.71\t\t',
#   '\n\t\t\t31545\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t91\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/1XA2-niwTBa0HEB7hOz3Dw__micro/img/yhbf5YV6KtavOaIVcFC1ZrDQE_0=/fit-in/64x64/filters:strip_icc()/pic4530974.jpg',
#   '\n\n\nThe Lord of the Rings: Journeys in Middle-Earth\n(2019)\n\n\n\t\t\tHeroes explore Middle-earth, working together to combat evil in an epic campaign.\n\t\t\n',
#   '\n\t\t\t7.548\t\t',
#   '\n\t\t\t8.00\t\t',
#   '\n\t\t\t11918\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t92\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/hXdfAhgZ8OeyWLunt36wlw__micro/img/qdkWYsmTq_dyuJU5YCVCZMQrkAI=/fit-in/64x64/filters:strip_icc()/pic3578101.jpg',
#   '\n\n\nRaiders of the North Sea\n(2015)\n\n\n\t\t\tGather your Viking crew in order to plunder seas and lands for glory!\n\t\t\n',
#   '\n\t\t\t7.546\t\t',
#   '\n\t\t\t7.77\t\t',
#   '\n\t\t\t19037\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t93\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/oxdsZKIX5_3ovDo38EIaeg__micro/img/gx6OxFzIkjvAvXPs8CDcucwwhak=/fit-in/64x64/filters:strip_icc()/pic1872452.jpg',
#   '\n\n\nEldritch Horror\n(2013)\n\n\n\t\t\tAn unknown Elder God approaches the world—and you must solve mysteries to stop it.\n\t\t\n',
#   '\n\t\t\t7.545\t\t',
#   '\n\t\t\t7.78\t\t',
#   '\n\t\t\t32064\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t94\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/VceWk5QVkgIp6rWDl5qHKQ__micro/img/nHZMadoKR1T5fSg9V6rkR3e39M0=/fit-in/64x64/filters:strip_icc()/pic2611318.jpg',
#   '\n\n\nMombasa\n(2015)\n\n\n\t\t\tAcquire shares of unique companies and propagate their trading posts to rake in cash.\n\t\t\n',
#   '\n\t\t\t7.545\t\t',
#   '\n\t\t\t7.87\t\t',
#   '\n\t\t\t11842\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t95\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/MjeJZfulbsM1DSV3DrGJYA__micro/img/x2BDobiHVhQHl7LhBimeU8L1ko4=/fit-in/64x64/filters:strip_icc()/pic5100691.jpg',
#   '\n\n\nCascadia\n(2021)\n\n\n\t\t\tCreate the most harmonious ecosystem as you puzzle together habitats and wildlife.\n\t\t\n',
#   '\n\t\t\t7.532\t\t',
#   '\n\t\t\t8.08\t\t',
#   '\n\t\t\t7239\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t96\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/8G6GkImjt0F_L5aYb8fmtQ__micro/img/kDuDqsd-uzh0n9aqlsEoHXZbgfY=/fit-in/64x64/filters:strip_icc()/pic3175535.jpg',
#   '\n\n\nLorenzo il Magnifico\n(2016)\n\n\n\t\t\tAvoid excommunication and lead your family to power during the Italian Renaissance.\n\t\t\n',
#   '\n\t\t\t7.530\t\t',
#   '\n\t\t\t7.88\t\t',
#   '\n\t\t\t11147\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t97\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/iwevA6XmiNLHn1QnGUucqw__micro/img/CGB3Ihk0wWICh8wG6_Wp2pbGoCk=/fit-in/64x64/filters:strip_icc()/pic3880340.jpg',
#   '\n\n\nRising Sun\n(2018)\n\n\n\t\t\tLead your clan to victory through negotiation, combat, monsters and favors from Kami.\n\t\t\n',
#   '\n\t\t\t7.528\t\t',
#   '\n\t\t\t7.82\t\t',
#   '\n\t\t\t17990\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t98\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/soAzNVWglCdVBacNjoCTJw__micro/img/7MXTV2Z2rBL40blbo6F8e1RBeRo=/fit-in/64x64/filters:strip_icc()/pic2338267.jpg',
#   '\n\n\nTigris & Euphrates\n(1997)\n\n\n\t\t\tKeep your Mesopotamian civilisation in perfect balance through revolutions and wars.\n\t\t\n',
#   '\n\t\t\t7.527\t\t',
#   '\n\t\t\t7.70\t\t',
#   '\n\t\t\t26491\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t99\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/AuAheDzhkLufiZFE9JaRNA__micro/img/rx1j8qFjOrmsWHaQhseRKppXKSA=/fit-in/64x64/filters:strip_icc()/pic4781085.jpg',
#   '\n\n\nThe Isle of Cats\n(2019)\n\n\n\t\t\tRescue as many island cats as you can before Lord Vesh comes to destroy their home.\n\t\t\n',
#   '\n\t\t\t7.526\t\t',
#   '\n\t\t\t7.88\t\t',
#   '\n\t\t\t12784\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t'],
#  ['\n\t\t\t100\t\t\t\n\t\t\t\t\t',
#   'https://cf.geekdo-images.com/wLW7pFn0--20lEizEz5p3A__micro/img/HGRTd0C4poFciUwMZzBt6On1R3Y=/fit-in/64x64/filters:strip_icc()/pic2270442.jpg',
#   '\n\n\nPatchwork\n(2014)\n\n\n\t\t\tPiece together a quilt and leave no holes to become the button master.\n\t\t\n',
#   '\n\t\t\t7.526\t\t',
#   '\n\t\t\t7.63\t\t',
#   '\n\t\t\t54050\t\t',
#   '\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t[Shop]\n\t\t\t\t\t']]

# %%
# convert the data to a Spark SQL table named board_games in the games database
import pyspark.sql.functions as f
from pyspark.sql.types import *
 
board_games = spark.createDataFrame(all_data, schema=header)
 
for col_name in board_games.columns:
  new_col_name = col_name.title().strip().replace(' ', '')
  board_games = board_games.withColumnRenamed(col_name, new_col_name)
  
board_games = board_games.drop('Shop')

display(board_games) #verify Shop was dropped
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>BoardGameRank</th><th>ThumbnailImage</th><th>Title</th><th>GeekRating</th><th>AvgRating</th><th>NumVoters</th></tr></thead><tbody><tr><td>
# 			1
# 					</td><td>https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__micro/img/sQyh47ClBO3d5sxPm73hMvM-JV4=/fit-in/64x64/filters:strip_icc()/pic2437871.jpg</td><td>
#
#
# Gloomhaven
# (2017)
#
#
# 			Vanquish monsters with strategic cardplay. Fulfill your quest to leave your legacy!
#
# </td><td>
# 			8.499		</td><td>
# 			8.73		</td><td>
# 			49467		</td></tr><tr><td>
# 			2
# 					</td><td>https://cf.geekdo-images.com/-Qer2BBPG7qGGDu6KcVDIw__micro/img/n6-sXYD6XXZoqIxq4P6AG7VPCuA=/fit-in/64x64/filters:strip_icc()/pic2452831.png</td><td>
#
#
# Pandemic Legacy: Season 1
# (2015)
#
#
# 			Mutating diseases are spreading around the world - can your team save humanity?
#
# </td><td>
# 			8.437		</td><td>
# 			8.59		</td><td>
# 			46063		</td></tr><tr><td>
# 			3
# 					</td><td>https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__micro/img/4Od3GYCiqptga0VbmyumPbJlBsU=/fit-in/64x64/filters:strip_icc()/pic3490053.jpg</td><td>
#
#
# Brass: Birmingham
# (2018)
#
#
# 			Build networks, grow industries, and navigate the world of the Industrial Revolution.
#
# </td><td>
# 			8.422		</td><td>
# 			8.66		</td><td>
# 			27313		</td></tr><tr><td>
# 			4
# 					</td><td>https://cf.geekdo-images.com/wg9oOLcsKvDesSUdZQ4rxw__micro/img/LUkXZhd1TO80eCiXMD3-KfnzA6k=/fit-in/64x64/filters:strip_icc()/pic3536616.jpg</td><td>
#
#
# Terraforming Mars
# (2016)
#
#
# 			Compete with rival CEOs to make Mars habitable and build your corporate empire.
#
# </td><td>
# 			8.269		</td><td>
# 			8.41		</td><td>
# 			77092		</td></tr><tr><td>
# 			5
# 					</td><td>https://cf.geekdo-images.com/_HhIdavYW-hid20Iq3hhmg__micro/img/OdKjWiFsNvQAfJfXXSITttiozWE=/fit-in/64x64/filters:strip_icc()/pic5055631.jpg</td><td>
#
#
# Gloomhaven: Jaws of the Lion
# (2020)
#
#
# 			Vanquish monsters with strategic cardplay in a 25-scenario Gloomhaven campaign.
#
# </td><td>
# 			8.267		</td><td>
# 			8.65		</td><td>
# 			18306		</td></tr><tr><td>
# 			6
# 					</td><td>https://cf.geekdo-images.com/_Ppn5lssO5OaildSE-FgFA__micro/img/2gymaKs35_2yj7eyyA6cYyVmd9c=/fit-in/64x64/filters:strip_icc()/pic3727516.jpg</td><td>
#
#
# Twilight Imperium: Fourth Edition
# (2017)
#
#
# 			Build an intergalactic empire through trade, research, conquest and grand politics.
#
# </td><td>
# 			8.256		</td><td>
# 			8.66		</td><td>
# 			16792		</td></tr><tr><td>
# 			7
# 					</td><td>https://cf.geekdo-images.com/hGWFm3hbMlCDsfCsauOQ4g__micro/img/odWj2bEnZi9dEcQQrOtYj1e0QLE=/fit-in/64x64/filters:strip_icc()/pic5375625.png</td><td>
#
#
# Gaia Project
# (2017)
#
#
# 			Expand, research, upgrade, and settle the galaxy with one of 14 alien species.
#
# </td><td>
# 			8.173		</td><td>
# 			8.47		</td><td>
# 			20213		</td></tr><tr><td>
# 			8
# 					</td><td>https://cf.geekdo-images.com/7SrPNGBKg9IIsP4UQpOi8g__micro/img/nEvTiCkWpT-ymH4bstc9c335TtQ=/fit-in/64x64/filters:strip_icc()/pic4325841.jpg</td><td>
#
#
# Star Wars: Rebellion
# (2016)
#
#
# 			Strike from your hidden base as the Rebels—or find and destroy it as the Empire.
#
# </td><td>
# 			8.169		</td><td>
# 			8.42		</td><td>
# 			26313		</td></tr><tr><td>
# 			9
# 					</td><td>https://cf.geekdo-images.com/a13ieMPP2s0KEaKNYmtH5w__micro/img/HQaHfx5cy6wJtZBMZCbVeNbfdy8=/fit-in/64x64/filters:strip_icc()/pic3615739.png</td><td>
#
#
# Spirit Island
# (2017)
#
#
# 			Island Spirits join forces using elemental powers to defend their home from invaders.
#
# </td><td>
# 			8.142		</td><td>
# 			8.36		</td><td>
# 			34294		</td></tr><tr><td>
# 			10
# 					</td><td>https://cf.geekdo-images.com/ImPgGag98W6gpV1KV812aA__micro/img/NT-Av_3kdYUcwuti5ocmIQXow3g=/fit-in/64x64/filters:strip_icc()/pic1215633.jpg</td><td>
#
#
# War of the Ring: Second Edition
# (2011)
#
#
# 			The Fellowship and the Free Peoples clash with Sauron over the fate of Middle-Earth.
#
# </td><td>
# 			8.141		</td><td>
# 			8.52		</td><td>
# 			16056		</td></tr><tr><td>
# 			11
# 					</td><td>https://cf.geekdo-images.com/fVwPntkJKgaEo0rIC0RwpA__micro/img/77dZJpqtydc8TTecl0ReGF7iAVw=/fit-in/64x64/filters:strip_icc()/pic2663291.jpg</td><td>
#
#
# Through the Ages: A New Story of Civilization
# (2015)
#
#
# 			Rewrite history as you build up your civilization in this epic card drafting game!
#
# </td><td>
# 			8.141		</td><td>
# 			8.37		</td><td>
# 			26312		</td></tr><tr><td>
# 			12
# 					</td><td>https://cf.geekdo-images.com/u1l0gH7sb_vnvDvoO_QHqA__micro/img/xeShpQfbj4L1id-ItJbfIYVzgyA=/fit-in/64x64/filters:strip_icc()/pic4887376.jpg</td><td>
#
#
# Great Western Trail
# (2016)
#
#
# 			Use strategic outposts and navigate danger as you herd your cattle to Kansas City.
#
# </td><td>
# 			8.120		</td><td>
# 			8.29		</td><td>
# 			33958		</td></tr><tr><td>
# 			13
# 					</td><td>https://cf.geekdo-images.com/pNCiUUphnoeWOYfsWq0kng__micro/img/ZlfJiIATIt5MY7xWSMzFmdygaa0=/fit-in/64x64/filters:strip_icc()/pic3530661.jpg</td><td>
#
#
# Twilight Struggle
# (2005)
#
#
# 			Relive the Cold War and rewrite history in an epic clash between the USA and USSR.
#
# </td><td>
# 			8.110		</td><td>
# 			8.28		</td><td>
# 			43671		</td></tr><tr><td>
# 			14
# 					</td><td>https://cf.geekdo-images.com/7k_nOxpO9OGIjhLq2BUZdA__micro/img/ETplc22GdhlN5u0mppcDxSP8LVk=/fit-in/64x64/filters:strip_icc()/pic3163924.jpg</td><td>
#
#
# Scythe
# (2016)
#
#
# 			Five factions vie for dominance in a war-torn, mech-filled, dieselpunk 1920s Europe.
#
# </td><td>
# 			8.059		</td><td>
# 			8.21		</td><td>
# 			66884		</td></tr><tr><td>
# 			15
# 					</td><td>https://cf.geekdo-images.com/PhjygpWSo-0labGrPBMyyg__micro/img/mfU7-dEFnVyXJrF-BWAO0buexao=/fit-in/64x64/filters:strip_icc()/pic5666597.jpg</td><td>
#
#
# Dune: Imperium
# (2020)
#
#
# 			Influence, intrigue, and combat in the universe of Dune.
#
# </td><td>
# 			8.018		</td><td>
# 			8.33		</td><td>
# 			18424		</td></tr><tr><td>
# 			16
# 					</td><td>https://cf.geekdo-images.com/5CFwjd8zTcGYVUnkXh04hw__micro/img/N1VrEUaW6bmwnqbZfi2nRScwGxM=/fit-in/64x64/filters:strip_icc()/pic1176894.jpg</td><td>
#
#
# The Castles of Burgundy
# (2011)
#
#
# 			Plan, trade, and build your Burgundian estate to prosperity and prominence.
#
# </td><td>
# 			8.006		</td><td>
# 			8.13		</td><td>
# 			51864		</td></tr><tr><td>
# 			17
# 					</td><td>https://cf.geekdo-images.com/tAqLpWxQ0Oo3GaPP3MER1g__micro/img/tivhH093LwCowK-_S7bVF_xha34=/fit-in/64x64/filters:strip_icc()/pic5073276.jpg</td><td>
#
#
# Nemesis
# (2018)
#
#
# 			Survive an alien-infested spaceship but beware of other players and their agendas.
#
# </td><td>
# 			7.987		</td><td>
# 			8.38		</td><td>
# 			19175		</td></tr><tr><td>
# 			18
# 					</td><td>https://cf.geekdo-images.com/WzNs1mA_o22ZWTR8fkLP2g__micro/img/xh3isprMbt_FCg9vs3w_ifv-JXY=/fit-in/64x64/filters:strip_icc()/pic3376065.jpg</td><td>
#
#
# 7 Wonders Duel
# (2015)
#
#
# 			Science? Military? What will you draft to win this head-to-head version of 7 Wonders?
#
# </td><td>
# 			7.983		</td><td>
# 			8.11		</td><td>
# 			72475		</td></tr><tr><td>
# 			19
# 					</td><td>https://cf.geekdo-images.com/CzwSm8i7tkLz6cBnrILZBg__micro/img/FQyxREkHBn7yTbGmBg7c44eLgaM=/fit-in/64x64/filters:strip_icc()/pic3453267.jpg</td><td>
#
#
# Concordia
# (2013)
#
#
# 			Lead your Roman dynasty and build the greatest trading empire in the Mediterranean.
#
# </td><td>
# 			7.968		</td><td>
# 			8.12		</td><td>
# 			32560		</td></tr><tr><td>
# 			20
# 					</td><td>https://cf.geekdo-images.com/tHVtPzu82mBpeQbbZkV6EA__micro/img/jM8d5Q5btvJmcWQN_px-A-nlueI=/fit-in/64x64/filters:strip_icc()/pic3469216.jpg</td><td>
#
#
# Brass: Lancashire
# (2007)
#
#
# 			Test your economic mettle as you build and network in the Industrial Revolution.
#
# </td><td>
# 			7.966		</td><td>
# 			8.18		</td><td>
# 			21314		</td></tr><tr><td>
# 			21
# 					</td><td>https://cf.geekdo-images.com/bre12I1YiXkZr7elvriz4A__micro/img/SAwaBrDhHbGuq6dFY-ok95qFMcU=/fit-in/64x64/filters:strip_icc()/pi

# %%
#create regex to use for parsing
regex_pattern = r'^(.*)\((\d*)\)(.*)$'
 
# Parsing to create the YearPublished from Title data and dropping the description of the game
parse_board_games = (
  board_games
    .withColumn('Title', f.regexp_replace('Title', r'\n|\t', ''))
    .withColumn('YearPublished', f.regexp_extract('Title', regex_pattern, 2))
    .withColumn('Title', f.regexp_extract('Title', regex_pattern, 1))
)

display(parse_board_games)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>BoardGameRank</th><th>ThumbnailImage</th><th>Title</th><th>GeekRating</th><th>AvgRating</th><th>NumVoters</th><th>YearPublished</th></tr></thead><tbody><tr><td>
# 			1
# 					</td><td>https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__micro/img/sQyh47ClBO3d5sxPm73hMvM-JV4=/fit-in/64x64/filters:strip_icc()/pic2437871.jpg</td><td>Gloomhaven</td><td>
# 			8.499		</td><td>
# 			8.73		</td><td>
# 			49467		</td><td>2017</td></tr><tr><td>
# 			2
# 					</td><td>https://cf.geekdo-images.com/-Qer2BBPG7qGGDu6KcVDIw__micro/img/n6-sXYD6XXZoqIxq4P6AG7VPCuA=/fit-in/64x64/filters:strip_icc()/pic2452831.png</td><td>Pandemic Legacy: Season 1</td><td>
# 			8.437		</td><td>
# 			8.59		</td><td>
# 			46063		</td><td>2015</td></tr><tr><td>
# 			3
# 					</td><td>https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__micro/img/4Od3GYCiqptga0VbmyumPbJlBsU=/fit-in/64x64/filters:strip_icc()/pic3490053.jpg</td><td>Brass: Birmingham</td><td>
# 			8.422		</td><td>
# 			8.66		</td><td>
# 			27313		</td><td>2018</td></tr><tr><td>
# 			4
# 					</td><td>https://cf.geekdo-images.com/wg9oOLcsKvDesSUdZQ4rxw__micro/img/LUkXZhd1TO80eCiXMD3-KfnzA6k=/fit-in/64x64/filters:strip_icc()/pic3536616.jpg</td><td>Terraforming Mars</td><td>
# 			8.269		</td><td>
# 			8.41		</td><td>
# 			77092		</td><td>2016</td></tr><tr><td>
# 			5
# 					</td><td>https://cf.geekdo-images.com/_HhIdavYW-hid20Iq3hhmg__micro/img/OdKjWiFsNvQAfJfXXSITttiozWE=/fit-in/64x64/filters:strip_icc()/pic5055631.jpg</td><td>Gloomhaven: Jaws of the Lion</td><td>
# 			8.267		</td><td>
# 			8.65		</td><td>
# 			18306		</td><td>2020</td></tr><tr><td>
# 			6
# 					</td><td>https://cf.geekdo-images.com/_Ppn5lssO5OaildSE-FgFA__micro/img/2gymaKs35_2yj7eyyA6cYyVmd9c=/fit-in/64x64/filters:strip_icc()/pic3727516.jpg</td><td>Twilight Imperium: Fourth Edition</td><td>
# 			8.256		</td><td>
# 			8.66		</td><td>
# 			16792		</td><td>2017</td></tr><tr><td>
# 			7
# 					</td><td>https://cf.geekdo-images.com/hGWFm3hbMlCDsfCsauOQ4g__micro/img/odWj2bEnZi9dEcQQrOtYj1e0QLE=/fit-in/64x64/filters:strip_icc()/pic5375625.png</td><td>Gaia Project</td><td>
# 			8.173		</td><td>
# 			8.47		</td><td>
# 			20213		</td><td>2017</td></tr><tr><td>
# 			8
# 					</td><td>https://cf.geekdo-images.com/7SrPNGBKg9IIsP4UQpOi8g__micro/img/nEvTiCkWpT-ymH4bstc9c335TtQ=/fit-in/64x64/filters:strip_icc()/pic4325841.jpg</td><td>Star Wars: Rebellion</td><td>
# 			8.169		</td><td>
# 			8.42		</td><td>
# 			26313		</td><td>2016</td></tr><tr><td>
# 			9
# 					</td><td>https://cf.geekdo-images.com/a13ieMPP2s0KEaKNYmtH5w__micro/img/HQaHfx5cy6wJtZBMZCbVeNbfdy8=/fit-in/64x64/filters:strip_icc()/pic3615739.png</td><td>Spirit Island</td><td>
# 			8.142		</td><td>
# 			8.36		</td><td>
# 			34294		</td><td>2017</td></tr><tr><td>
# 			10
# 					</td><td>https://cf.geekdo-images.com/ImPgGag98W6gpV1KV812aA__micro/img/NT-Av_3kdYUcwuti5ocmIQXow3g=/fit-in/64x64/filters:strip_icc()/pic1215633.jpg</td><td>War of the Ring: Second Edition</td><td>
# 			8.141		</td><td>
# 			8.52		</td><td>
# 			16056		</td><td>2011</td></tr><tr><td>
# 			11
# 					</td><td>https://cf.geekdo-images.com/fVwPntkJKgaEo0rIC0RwpA__micro/img/77dZJpqtydc8TTecl0ReGF7iAVw=/fit-in/64x64/filters:strip_icc()/pic2663291.jpg</td><td>Through the Ages: A New Story of Civilization</td><td>
# 			8.141		</td><td>
# 			8.37		</td><td>
# 			26312		</td><td>2015</td></tr><tr><td>
# 			12
# 					</td><td>https://cf.geekdo-images.com/u1l0gH7sb_vnvDvoO_QHqA__micro/img/xeShpQfbj4L1id-ItJbfIYVzgyA=/fit-in/64x64/filters:strip_icc()/pic4887376.jpg</td><td>Great Western Trail</td><td>
# 			8.120		</td><td>
# 			8.29		</td><td>
# 			33958		</td><td>2016</td></tr><tr><td>
# 			13
# 					</td><td>https://cf.geekdo-images.com/pNCiUUphnoeWOYfsWq0kng__micro/img/ZlfJiIATIt5MY7xWSMzFmdygaa0=/fit-in/64x64/filters:strip_icc()/pic3530661.jpg</td><td>Twilight Struggle</td><td>
# 			8.110		</td><td>
# 			8.28		</td><td>
# 			43671		</td><td>2005</td></tr><tr><td>
# 			14
# 					</td><td>https://cf.geekdo-images.com/7k_nOxpO9OGIjhLq2BUZdA__micro/img/ETplc22GdhlN5u0mppcDxSP8LVk=/fit-in/64x64/filters:strip_icc()/pic3163924.jpg</td><td>Scythe</td><td>
# 			8.059		</td><td>
# 			8.21		</td><td>
# 			66884		</td><td>2016</td></tr><tr><td>
# 			15
# 					</td><td>https://cf.geekdo-images.com/PhjygpWSo-0labGrPBMyyg__micro/img/mfU7-dEFnVyXJrF-BWAO0buexao=/fit-in/64x64/filters:strip_icc()/pic5666597.jpg</td><td>Dune: Imperium</td><td>
# 			8.018		</td><td>
# 			8.33		</td><td>
# 			18424		</td><td>2020</td></tr><tr><td>
# 			16
# 					</td><td>https://cf.geekdo-images.com/5CFwjd8zTcGYVUnkXh04hw__micro/img/N1VrEUaW6bmwnqbZfi2nRScwGxM=/fit-in/64x64/filters:strip_icc()/pic1176894.jpg</td><td>The Castles of Burgundy</td><td>
# 			8.006		</td><td>
# 			8.13		</td><td>
# 			51864		</td><td>2011</td></tr><tr><td>
# 			17
# 					</td><td>https://cf.geekdo-images.com/tAqLpWxQ0Oo3GaPP3MER1g__micro/img/tivhH093LwCowK-_S7bVF_xha34=/fit-in/64x64/filters:strip_icc()/pic5073276.jpg</td><td>Nemesis</td><td>
# 			7.987		</td><td>
# 			8.38		</td><td>
# 			19175		</td><td>2018</td></tr><tr><td>
# 			18
# 					</td><td>https://cf.geekdo-images.com/WzNs1mA_o22ZWTR8fkLP2g__micro/img/xh3isprMbt_FCg9vs3w_ifv-JXY=/fit-in/64x64/filters:strip_icc()/pic3376065.jpg</td><td>7 Wonders Duel</td><td>
# 			7.983		</td><td>
# 			8.11		</td><td>
# 			72475		</td><td>2015</td></tr><tr><td>
# 			19
# 					</td><td>https://cf.geekdo-images.com/CzwSm8i7tkLz6cBnrILZBg__micro/img/FQyxREkHBn7yTbGmBg7c44eLgaM=/fit-in/64x64/filters:strip_icc()/pic3453267.jpg</td><td>Concordia</td><td>
# 			7.968		</td><td>
# 			8.12		</td><td>
# 			32560		</td><td>2013</td></tr><tr><td>
# 			20
# 					</td><td>https://cf.geekdo-images.com/tHVtPzu82mBpeQbbZkV6EA__micro/img/jM8d5Q5btvJmcWQN_px-A-nlueI=/fit-in/64x64/filters:strip_icc()/pic3469216.jpg</td><td>Brass: Lancashire</td><td>
# 			7.966		</td><td>
# 			8.18		</td><td>
# 			21314		</td><td>2007</td></tr><tr><td>
# 			21
# 					</td><td>https://cf.geekdo-images.com/bre12I1YiXkZr7elvriz4A__micro/img/SAwaBrDhHbGuq6dFY-ok95qFMcU=/fit-in/64x64/filters:strip_icc()/pic5375624.jpg</td><td>Terra Mystica</td><td>
# 			7.958		</td><td>
# 			8.12		</td><td>
# 			42539		</td><td>2012</td></tr><tr><td>
# 			22
# 					</td><td>https://cf.geekdo-images.com/s9oGMCo1fcfV4Dk3EnqLZw__micro/img/JCrcuFDrjVQ64uLbqpH-Pmg6XsU=/fit-in/64x64/filters:strip_icc()/pic3146943.png</td><td>A Feast for Odin</td><td>
# 			7.953		</td><td>
# 			8.20		</td><td>
# 			21370		</td><td>2016</td></tr><tr><td>
# 			23
# 					</td><td>https://cf.geekdo-images.com/yLZJCVLlIx4c7eJEWUNJ7w__micro/img/5ZaRePVhfelfofF7T_OC1e0gUCw=/fit-in/64x64/filters:strip_icc()/pic4458123.jpg</td><td>Wingspan</td><td>
# 			7.943		</td><td>
# 			8.10		</td><td>
# 			60195		</td><td>2019</td></tr><tr><td>
# 			24
# 					</td><td>https://cf.geekdo-images.com/RdCWCXPnBGSxoOhk5Hkq_g__micro/img/TVx3_34ywzwURntW1WMKBx6ZeCg=/fit-in/64x64/filters:strip_icc()/pic6530423.jpg</td><td>Arkham Horror: The Card Game</td><td>
# 			7.926		</td><td>
# 			8.16		</td><td>
# 			34490		</td><td>2016</td></tr><tr><td>
# 			25
# 					</td><td>https://cf.geekdo-images.com/l_PRU2lVlX9seScRFcvFlA__micro/img/3EqHlTkNSnZNFHVaAeFSpzfzuIQ=/fit-in/64x64/filters:strip_icc()/pic6500949.jpg</td><td>Viticulture Essential Edition</td><td>
# 			7.891		</td><td>
# 			8.05		</td><td>
# 			36505		</td><td>2015</td></tr><tr><td>
# 			26
# 					</td><td>https://cf.geekdo-images.com/JUAUWaVUzeBgzirhZNmHHw__micro/img/tdHLiMYfi-KTy89sGBGZVeE9ts0=/fit-in/64x64/filters:strip_icc()/pic4254509.jpg</td><td>Root</td><td>
# 			7.889		</td><td>
# 			8.10		</td><td>
# 			33655		</td><td>2018</td></tr><tr><td>
# 			27
# 					</td><td>https://cf.geekdo-images.com/nagl1li6kYt9elV9jbfVQw__micro/img/hUKCvnqgFvTl0aOMd8FLkgCObT0=/fit-in/64x64/filters:strip_icc()/pic6228507.jpg</td><td>Orléans</td><td>
# 			7.884		</td><

# %%
#Cleaning the parsed data

clean_board_games = (
  parse_board_games
    .withColumnRenamed('BoardGameRank', 'Rank')
    .withColumnRenamed('ThumbnailImage', 'ImageURL')
    .withColumn('Rank', f.col('Rank').cast(IntegerType()))
    .withColumn('GeekRating', f.col('GeekRating').cast(FloatType()))
    .withColumn('AvgRating', f.col('AvgRating').cast(FloatType()))
    .withColumn('NumVoters', f.col('NumVoters').cast(IntegerType()))
    .withColumn('YearPublished', f.col('YearPublished').cast(IntegerType()))
)

display(clean_board_games) #verify table is cleaned
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Rank</th><th>ImageURL</th><th>Title</th><th>GeekRating</th><th>AvgRating</th><th>NumVoters</th><th>YearPublished</th></tr></thead><tbody><tr><td>1</td><td>https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__micro/img/sQyh47ClBO3d5sxPm73hMvM-JV4=/fit-in/64x64/filters:strip_icc()/pic2437871.jpg</td><td>Gloomhaven</td><td>8.499</td><td>8.73</td><td>49467</td><td>2017</td></tr><tr><td>2</td><td>https://cf.geekdo-images.com/-Qer2BBPG7qGGDu6KcVDIw__micro/img/n6-sXYD6XXZoqIxq4P6AG7VPCuA=/fit-in/64x64/filters:strip_icc()/pic2452831.png</td><td>Pandemic Legacy: Season 1</td><td>8.437</td><td>8.59</td><td>46063</td><td>2015</td></tr><tr><td>3</td><td>https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__micro/img/4Od3GYCiqptga0VbmyumPbJlBsU=/fit-in/64x64/filters:strip_icc()/pic3490053.jpg</td><td>Brass: Birmingham</td><td>8.422</td><td>8.66</td><td>27313</td><td>2018</td></tr><tr><td>4</td><td>https://cf.geekdo-images.com/wg9oOLcsKvDesSUdZQ4rxw__micro/img/LUkXZhd1TO80eCiXMD3-KfnzA6k=/fit-in/64x64/filters:strip_icc()/pic3536616.jpg</td><td>Terraforming Mars</td><td>8.269</td><td>8.41</td><td>77092</td><td>2016</td></tr><tr><td>5</td><td>https://cf.geekdo-images.com/_HhIdavYW-hid20Iq3hhmg__micro/img/OdKjWiFsNvQAfJfXXSITttiozWE=/fit-in/64x64/filters:strip_icc()/pic5055631.jpg</td><td>Gloomhaven: Jaws of the Lion</td><td>8.267</td><td>8.65</td><td>18306</td><td>2020</td></tr><tr><td>6</td><td>https://cf.geekdo-images.com/_Ppn5lssO5OaildSE-FgFA__micro/img/2gymaKs35_2yj7eyyA6cYyVmd9c=/fit-in/64x64/filters:strip_icc()/pic3727516.jpg</td><td>Twilight Imperium: Fourth Edition</td><td>8.256</td><td>8.66</td><td>16792</td><td>2017</td></tr><tr><td>7</td><td>https://cf.geekdo-images.com/hGWFm3hbMlCDsfCsauOQ4g__micro/img/odWj2bEnZi9dEcQQrOtYj1e0QLE=/fit-in/64x64/filters:strip_icc()/pic5375625.png</td><td>Gaia Project</td><td>8.173</td><td>8.47</td><td>20213</td><td>2017</td></tr><tr><td>8</td><td>https://cf.geekdo-images.com/7SrPNGBKg9IIsP4UQpOi8g__micro/img/nEvTiCkWpT-ymH4bstc9c335TtQ=/fit-in/64x64/filters:strip_icc()/pic4325841.jpg</td><td>Star Wars: Rebellion</td><td>8.169</td><td>8.42</td><td>26313</td><td>2016</td></tr><tr><td>9</td><td>https://cf.geekdo-images.com/a13ieMPP2s0KEaKNYmtH5w__micro/img/HQaHfx5cy6wJtZBMZCbVeNbfdy8=/fit-in/64x64/filters:strip_icc()/pic3615739.png</td><td>Spirit Island</td><td>8.142</td><td>8.36</td><td>34294</td><td>2017</td></tr><tr><td>10</td><td>https://cf.geekdo-images.com/ImPgGag98W6gpV1KV812aA__micro/img/NT-Av_3kdYUcwuti5ocmIQXow3g=/fit-in/64x64/filters:strip_icc()/pic1215633.jpg</td><td>War of the Ring: Second Edition</td><td>8.141</td><td>8.52</td><td>16056</td><td>2011</td></tr><tr><td>11</td><td>https://cf.geekdo-images.com/fVwPntkJKgaEo0rIC0RwpA__micro/img/77dZJpqtydc8TTecl0ReGF7iAVw=/fit-in/64x64/filters:strip_icc()/pic2663291.jpg</td><td>Through the Ages: A New Story of Civilization</td><td>8.141</td><td>8.37</td><td>26312</td><td>2015</td></tr><tr><td>12</td><td>https://cf.geekdo-images.com/u1l0gH7sb_vnvDvoO_QHqA__micro/img/xeShpQfbj4L1id-ItJbfIYVzgyA=/fit-in/64x64/filters:strip_icc()/pic4887376.jpg</td><td>Great Western Trail</td><td>8.12</td><td>8.29</td><td>33958</td><td>2016</td></tr><tr><td>13</td><td>https://cf.geekdo-images.com/pNCiUUphnoeWOYfsWq0kng__micro/img/ZlfJiIATIt5MY7xWSMzFmdygaa0=/fit-in/64x64/filters:strip_icc()/pic3530661.jpg</td><td>Twilight Struggle</td><td>8.11</td><td>8.28</td><td>43671</td><td>2005</td></tr><tr><td>14</td><td>https://cf.geekdo-images.com/7k_nOxpO9OGIjhLq2BUZdA__micro/img/ETplc22GdhlN5u0mppcDxSP8LVk=/fit-in/64x64/filters:strip_icc()/pic3163924.jpg</td><td>Scythe</td><td>8.059</td><td>8.21</td><td>66884</td><td>2016</td></tr><tr><td>15</td><td>https://cf.geekdo-images.com/PhjygpWSo-0labGrPBMyyg__micro/img/mfU7-dEFnVyXJrF-BWAO0buexao=/fit-in/64x64/filters:strip_icc()/pic5666597.jpg</td><td>Dune: Imperium</td><td>8.018</td><td>8.33</td><td>18424</td>< ...

# %%
spark.conf.set('spark.sql.legacy.parquet.datetimeRebaseModeInWrite', 'CORRECTED')

spark.sql('DROP TABLE IF EXISTS games.board_games')

#Saving dataframe
(
  clean_board_games
    .select(
      'Rank',
      'ImageURL',
      'Title',
      'YearPublished',
      'GeekRating',
      'AvgRating',
      'NumVoters'
      )
    .write
    .format('delta')
    .mode('overwrite')
    .option('overwriteSchema', 'true')
    .saveAsTable('games.board_games')
)

# %% [markdown]
# Execute the following SQL statements to validate your results:

# %%
# %sql -- verify row count

SELECT COUNT(*) FROM games.board_games;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>100</td></tr></tbody></table></div>

# %%
# %sql -- verify values

SELECT * FROM games.board_games ORDER BY rank ASC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Rank</th><th>ImageURL</th><th>Title</th><th>YearPublished</th><th>GeekRating</th><th>AvgRating</th><th>NumVoters</th></tr></thead><tbody><tr><td>1</td><td>https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__micro/img/sQyh47ClBO3d5sxPm73hMvM-JV4=/fit-in/64x64/filters:strip_icc()/pic2437871.jpg</td><td>Gloomhaven</td><td>2017</td><td>8.499</td><td>8.73</td><td>49467</td></tr><tr><td>2</td><td>https://cf.geekdo-images.com/-Qer2BBPG7qGGDu6KcVDIw__micro/img/n6-sXYD6XXZoqIxq4P6AG7VPCuA=/fit-in/64x64/filters:strip_icc()/pic2452831.png</td><td>Pandemic Legacy: Season 1</td><td>2015</td><td>8.437</td><td>8.59</td><td>46063</td></tr><tr><td>3</td><td>https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__micro/img/4Od3GYCiqptga0VbmyumPbJlBsU=/fit-in/64x64/filters:strip_icc()/pic3490053.jpg</td><td>Brass: Birmingham</td><td>2018</td><td>8.422</td><td>8.66</td><td>27313</td></tr><tr><td>4</td><td>https://cf.geekdo-images.com/wg9oOLcsKvDesSUdZQ4rxw__micro/img/LUkXZhd1TO80eCiXMD3-KfnzA6k=/fit-in/64x64/filters:strip_icc()/pic3536616.jpg</td><td>Terraforming Mars</td><td>2016</td><td>8.269</td><td>8.41</td><td>77092</td></tr><tr><td>5</td><td>https://cf.geekdo-images.com/_HhIdavYW-hid20Iq3hhmg__micro/img/OdKjWiFsNvQAfJfXXSITttiozWE=/fit-in/64x64/filters:strip_icc()/pic5055631.jpg</td><td>Gloomhaven: Jaws of the Lion</td><td>2020</td><td>8.267</td><td>8.65</td><td>18306</td></tr><tr><td>6</td><td>https://cf.geekdo-images.com/_Ppn5lssO5OaildSE-FgFA__micro/img/2gymaKs35_2yj7eyyA6cYyVmd9c=/fit-in/64x64/filters:strip_icc()/pic3727516.jpg</td><td>Twilight Imperium: Fourth Edition</td><td>2017</td><td>8.256</td><td>8.66</td><td>16792</td></tr><tr><td>7</td><td>https://cf.geekdo-images.com/hGWFm3hbMlCDsfCsauOQ4g__micro/img/odWj2bEnZi9dEcQQrOtYj1e0QLE=/fit-in/64x64/filters:strip_icc()/pic5375625.png</td><td>Gaia Project</td><td>2017</td><td>8.173</td><td>8.47</td><td>20213</td></tr><tr><td>8</td><td>https://cf.geekdo-images.com/7SrPNGBKg9IIsP4UQpOi8g__micro/img/nEvTiCkWpT-ymH4bstc9c335TtQ=/fit-in/64x64/filters:strip_icc()/pic4325841.jpg</td><td>Star Wars: Rebellion</td><td>2016</td><td>8.169</td><td>8.42</td><td>26313</td></tr><tr><td>9</td><td>https://cf.geekdo-images.com/a13ieMPP2s0KEaKNYmtH5w__micro/img/HQaHfx5cy6wJtZBMZCbVeNbfdy8=/fit-in/64x64/filters:strip_icc()/pic3615739.png</td><td>Spirit Island</td><td>2017</td><td>8.142</td><td>8.36</td><td>34294</td></tr><tr><td>10</td><td>https://cf.geekdo-images.com/ImPgGag98W6gpV1KV812aA__micro/img/NT-Av_3kdYUcwuti5ocmIQXow3g=/fit-in/64x64/filters:strip_icc()/pic1215633.jpg</td><td>War of the Ring: Second Edition</td><td>2011</td><td>8.141</td><td>8.52</td><td>16056</td></tr><tr><td>11</td><td>https://cf.geekdo-images.com/fVwPntkJKgaEo0rIC0RwpA__micro/img/77dZJpqtydc8TTecl0ReGF7iAVw=/fit-in/64x64/filters:strip_icc()/pic2663291.jpg</td><td>Through the Ages: A New Story of Civilization</td><td>2015</td><td>8.141</td><td>8.37</td><td>26312</td></tr><tr><td>12</td><td>https://cf.geekdo-images.com/u1l0gH7sb_vnvDvoO_QHqA__micro/img/xeShpQfbj4L1id-ItJbfIYVzgyA=/fit-in/64x64/filters:strip_icc()/pic4887376.jpg</td><td>Great Western Trail</td><td>2016</td><td>8.12</td><td>8.29</td><td>33958</td></tr><tr><td>13</td><td>https://cf.geekdo-images.com/pNCiUUphnoeWOYfsWq0kng__micro/img/ZlfJiIATIt5MY7xWSMzFmdygaa0=/fit-in/64x64/filters:strip_icc()/pic3530661.jpg</td><td>Twilight Struggle</td><td>2005</td><td>8.11</td><td>8.28</td><td>43671</td></tr><tr><td>14</td><td>https://cf.geekdo-images.com/7k_nOxpO9OGIjhLq2BUZdA__micro/img/ETplc22GdhlN5u0mppcDxSP8LVk=/fit-in/64x64/filters:strip_icc()/pic3163924.jpg</td><td>Scythe</td><td>2016</td><td>8.059</td><td>8.21</td><td>66884</td></tr><tr><td>15</td><td>https://cf.geekdo-images.com/PhjygpWSo-0labGrPBMyyg__micro/img/mfU7-dEFnVyXJrF-BWAO0buexao=/fit-in/64x64/filters:strip_icc()/pic5666597.jpg</td><td>Dune: Imperium</td><td>2020</td><td>8.018</td><td>8.33</td><t ...

# %%
# %sql -- verify partitioning
DESCRIBE EXTENDED games.board_games;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>Rank</td><td>int</td><td></td></tr><tr><td>ImageURL</td><td>string</td><td></td></tr><tr><td>Title</td><td>string</td><td></td></tr><tr><td>YearPublished</td><td>int</td><td></td></tr><tr><td>GeekRating</td><td>float</td><td></td></tr><tr><td>AvgRating</td><td>float</td><td></td></tr><tr><td>NumVoters</td><td>int</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Not partitioned</td><td></td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Name</td><td>games.board_games</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/games.db/board_games</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>
